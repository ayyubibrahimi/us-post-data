# %%
import pandas as pd

# %%
df = pd.read_excel("../../../data/ND/II/North Dakota/Certified Officers/active-officers-per-agency-redacted-20231220144255.xlsx")

df
# Out:
#                                         Adams County SO  Unnamed: 1  \
# 0     Collins, Travis L.                            ...         NaN
# 1                                       General License         NaN
# 2     Emery, Shana D.                               ...         NaN
# 3                                       General License         NaN
# 4     Roehl, Andrew D.                              ...         NaN
# ...                                                 ...         ...
# 4462  Kuntz, Lucas J.                               ...         NaN
# 4463                                    General License         NaN
# 4464  Tunheim, Andrew J.                            ...         NaN
# 4465                                    General License         NaN
# 4466  Employees this Agency:                        ...         NaN
#
#      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['Adams County SO', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')
