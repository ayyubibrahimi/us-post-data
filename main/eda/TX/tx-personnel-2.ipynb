# %%
import pandas as pd

# %%
def read():
    df = pd.read_csv("../../../data/TX/2022-10-18/psr-data-rosters-4-years-20231220144255.csv", encoding='ISO-8859-1', on_bad_lines='skip')
    return df

# %%
df = read()

df.head(20)
# Out:
# /var/folders/4r/jhc99db14v58mjmncgtry0kc0000gn/T/ipykernel_10013/1712643494.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../../data/TX/2022-10-18/psr-data-rosters-4-years-20231220144255.csv", encoding='ISO-8859-1', on_bad_lines='skip')
#     UN_ID                                       ACADEMY_NAME  \
# 0     777                                        OSS Academy
# 1    6437                            TCLEOSE MITIGATING CIR.
# 2   11945                            TCLEOSE MITIGATING CIR.
# 3   14694                            TCLEOSE MITIGATING CIR.
# 4   15411  University of North Texas at Dallas Police Dep...
# 5   16338                                            Lexipol
# 6   18840                             Houston Police Academy
# 7   19089                                       TCOLE Online
# 8   23525                                        OSS Academy
# ...

# %%
# df = df.rename(columns={"FNAME": "first_name", "LNAME": "last_name", "MNAME": "middle_name"})

# df.loc[:, "first_name"] = df.first_name.str.lower().str.strip()
# df.loc[:, "middle_name"] = df.middle_name.str.lower().str.strip()
# df.loc[:, "last_name"] = df.last_name.str.lower().str.strip()

# %%
# df.head(20)

# %%
# df = df[df.last_name.isin(["chocklin"])]

# df
