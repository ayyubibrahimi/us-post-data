# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../../../download/data/Florida/Florida_index.csv")

    df = df.drop(columns=["suffix", "age", "rank"])

    df = df.rename(columns={"agency": "agency_name"})

    return df 

df = read_tbl()

df
# Out:
# /var/folders/4r/jhc99db14v58mjmncgtry0kc0000gn/T/ipykernel_9598/578989473.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../../download/data/Florida/Florida_index.csv")
#         person_nbr           full_name first_name middle_name  last_name  \
# 0            99996  Seborn E Blackburn     Seborn           E  Blackburn
# 1            99995      David A Thomas      David           A     Thomas
# 2            99995      David A Thomas      David           A     Thomas
# 3            99995      David A Thomas      David           A     Thomas
# 4            99994         Eric C Herb       Eric           C       Herb
# ...            ...                 ...        ...         ...        ...
# 646417         100       Barry J Smith      Barry           J      Smith
# 646418           1     Lex Lane Chance        Lex        Lane     Chance
# ...

# %%
df.to_csv("../data/output/florida_index.csv", index=False)

# %%
df.isna().sum()
# Out:
# person_nbr                0
# full_name                 0
# first_name                5
# middle_name           86108
# last_name                 0
# year_of_birth          1026
# agency_name               0
# type                      0
# start_date                0
# end_date             101440
# separation_reason    101451
# ever_revoked              0
# dtype: int64
