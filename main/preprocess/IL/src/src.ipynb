# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../../../download/data/Illinois/Illinois_index.csv")

    df = df.rename(columns={"agency": "agency_name"})

    return df 

df = read_tbl()

df
# Out:
#         person_nbr  last_name first_name middle_name  \
# 0         65000376      Adams       Mani           Y
# 1         65000377      Adams       Mark           A
# 2         65000377      Adams       Mark           A
# 3         65000378      Adams       Mark           F
# 4         65000379      Adams     Marvin           J
# ...            ...        ...        ...         ...
# 227394    65163907       Cook       Jada       Lenae
# 227395    65163908    Cintron  Christian       Oscar
# 227396    65163909     Chavez     Yesela         NaN
# 227397    65163910      Agron     Edward     Jovanie
# 227398    65163911      Lewis     Jayden           B
#
#                              race     sex  year_of_birth  \
# 0       Black or African American    Male           1974
# 1       Black or African American    Male           1964
# 2       Black or African American    Male           1964
# 3                           White    Male           1901
# ...

# %%
df.to_csv("../data/output/illinois_index.csv", index=False)
