# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../../../download/data/West Virginia/West_Virginia_index.csv")

    df = df.rename(columns={"agcy_name": "agency_name"})
    return df


df = read_tbl()

df.to_csv("../data/output/west_virginia_index.csv", index=False)
# Out:
#       person_nbr first_name  last_name initial_certification_date  \
# 0      0001-7902       JOHN      SYNER                 2004-04-09
# 1      0002-3178     GERALD     PAULEY                 1999-08-20
# 2      0002-3178     GERALD     PAULEY                 1999-08-20
# 3      0002-3178     GERALD     PAULEY                 1999-08-20
# 4      0003-3513    ANTHONY       BISE                 2006-04-28
# ...          ...        ...        ...                        ...
# 11418  9993-3822     LESLIE     BAILEY                 1986-10-14
# 11419  9993-3822     LESLIE     BAILEY                 1986-10-14
# 11420  9996-4096    MICHAEL    RANDALL                 2006-01-06
# 11421  9996-9358      LARRY  ZIMMERMAN                 1993-11-19
# 11422  9998-9217      LEWIS       PECK                 1983-11-14
#
#                                agency_name    end_date  start_date  \
# 0               WEST VIRGINIA STATE POLICE  2020-05-01  2003-09-29
# 1           PUTNAM COUNTY SHERIFF'S OFFICE  2006-05-31  1998-09-15
# 2      CERTIFICATION RETENTION POLICE DEPT  2018-03-17  2014-07-01
# 3              KANAWHA COUNTY PARKS POLICE         NaN  2018-03-17
# 4       MONONGALIA COUNTY SHERIFF'S OFFICE  2021-07-11  2005-10-15
# ...                                    ...         ...         ...
# 11418      RALEIGH COUNTY SHERIFF'S OFFICE  1986-07-16  1986-07-15
# 11419           WEST VIRGINIA STATE POLICE  2012-03-30  1901-01-01
# 11420        PARKERSBURG POLICE DEPARTMENT  2012-11-30  2005-09-16
# 11421         HUNTINGTON POLICE DEPARTMENT  2022-09-09  1993-08-19
# 11422         WIRT COUNTY SHERIFF'S OFFICE  2017-07-01  1978-02-18
#
#                           separation_reason       rank        full_name
# 0                 RESIGNED IN GOOD STANDING    OFFICER       JOHN SYNER
# 1                   RESIGNED STATUS UNKNOWN    OFFICER    GERALD PAULEY
# 2                 RESIGNED IN GOOD STANDING   CIVILIAN    GERALD PAULEY
# 3                                    ACTIVE  PATROLMAN    GERALD PAULEY
# 4                  RETIRED IN GOOD STANDING   SERGEANT     ANTHONY BISE
# ...                                     ...        ...              ...
# 11418  ASSUMED SEPARATED (END DATE UNKNOWN)    OFFICER    LESLIE BAILEY
# 11419                RETIRED STATUS UNKNOWN    OFFICER    LESLIE BAILEY
# 11420             RESIGNED IN GOOD STANDING    OFFICER  MICHAEL RANDALL
# 11421              RETIRED IN GOOD STANDING    CAPTAIN  LARRY ZIMMERMAN
# 11422              RETIRED IN GOOD STANDING   SERGEANT       LEWIS PECK
#
# [11423 rows x 10 columns]
