# %%
import pandas as pd
# import sys

# sys.path.append("../")

# %%
def read():
    dfa = pd.read_csv("../../../data/GA/2022-09-27/agency_data-20231220144255.csv", encoding="latin1")
    return dfa

# %%
df = read()
df
# Out:
#                                   AKEY                         NAME  \
# G1603       A.B.A.C. POLICE DEPARTMENT            38/2802 MOORE HWY
# G1639      ABBEVILLE POLICE DEPARTMENT          215 S. DEPOT STREET
# G1510        ACWORTH POLICE DEPARTMENT   4440 ACWORTH INDUSTRIAL DR
# G1129    ADAIRSVILLE POLICE DEPARTMENT            100 PUBLIC SQUARE
# G2496       Adel City Marshal's Office        112 N. Parrish Avenue
# ...                                ...                          ...
# G1003     WORTH COUNTY SHERIFFS OFFICE   201 N. MAIN STREET ROOM 14
# G1358          WRENS POLICE DEPARTMENT             401 BROAD STREET
# G1520   WRIGHTSVILLE POLICE DEPARTMENT     8653 SOUTH MARCUS STREET
# G1773         YOUNG HARRIS COLLEGE DPS             1 College Street
# G1102        ZEBULON POLICE DEPARTMENT                 P.O. BOX 385
#
#              ADDRESS  CITY    STATE                         ZIP          CEO  \
# ...
