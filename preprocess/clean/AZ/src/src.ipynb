# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../data/input/006_PR_AllOfficers_w_AppointmentsAndFinalActions.csv")

    # df = df.drop(columns=["suffix", "year_of_birth", "age", "type"])

    df = df.rename(columns={"Term_Desc": "separation_reason", 
                            "AppointedDate": "start_date",
                            "TerminationDate": "end_date",
                            "Last_Name": "last_name",
                            "First_Name": "first_name",
                            "Middle_Name": "middle_name",
                            "Agency": "agency_name",
                            "PostId": "person_nbr"})
    
    df = df[["agency_name", "person_nbr", "first_name", "middle_name", "last_name", "start_date", "end_date", "separation_reason"]]
    return df


def clean_separation_reason(df):
    df.loc[:, "separation_reason"] = (df.separation_reason
                                      .str.lower()
                                      .str.strip()
                                      .fillna("")
                                      .str.replace(r"misconduct - no|active|medical|other\/unknown", "", regex=True)
                                      .str.replace(r"misconduct - yes", "misconduct", regex=True)
                                      .str.replace(r"active", "", regex=True)
    )
    return df 


def clean_agency(df):
    df.loc[:, "agency_name"] = (df.agency_name
                           .str.lower()
                           .str.strip()
                           .str.replace(r"^az ", "arizona ", regex=True)
                           .str.replace(r" dept ", " department ", regex=False)
                           .str.replace(r"dept$", "department", regex=True)
                           .str.replace(r"departme$", "department", regex=True)
                           .str.replace(r" enf ", " enforcement ", regex=False)
                           .str.replace(r" az ", " arizona ", regex=False)
                           .str.replace(r" & ", " and ", regex=False)
                           .str.replace(r"contr$" ,"control", regex=True)
                           .str.replace(r"pd$", "police department", regex=True)
                           .str.replace(r"departm$", "department", regex=True)
                           .str.replace(r" cty ", " county ", regex=False)
                           .str.replace(r"-(\w+)$", r"- \1", regex=True )
                           .str.replace(r"(\w+)\,(\w+)", r"\1, \2", regex=True)
                           .str.replace(r"animal se", "animal services", regex=False)
                           .str.replace(r"^ret\,? ", "", regex=True)
    )
    return df 

df = read_tbl()

df = df.pipe(clean_separation_reason).pipe(clean_agency)

df
# Out:
#                                 agency_name  person_nbr first_name  \
# 0           maricopa county sheriffs office           1     Donald
# 1           maricopa county sheriffs office           2          J
# 2             pima law enforcement services           2          J
# 3      maricopa county parks and recreation           2          J
# 4                 phoenix police department           3          D
# ...                                     ...         ...        ...
# 69870      arizona game and fish department       72810    Matthew
# 69871      arizona game and fish department       72811    Zachary
# 69872   arizona department of public safety       72812    Matthew
# 69873   arizona department of public safety       72813    Michael
# 69874       maricopa county sheriffs office       72815     George
#
#       middle_name   last_name start_date end_date separation_reason
# 0               J   Nathaniel    4/24/00  4/26/00
# 1               R  Hanigsberg    8/25/79  3/11/81
# 2               R  Hanigsberg    6/10/84  5/15/85
# 3               R  Hanigsberg     4/7/85   6/3/87
# 4               A     Brookes    4/13/70  5/15/81
# ...           ...         ...        ...      ...               ...
# 69870       Keith      Waunch    3/19/25      NaN
# 69871         NaN       Lunow    3/19/25      NaN
# 69872     Anthony    Ebuhardt    3/20/25      NaN
# 69873      George       Julye    3/20/25      NaN
# 69874      Castro        Leon    3/20/25      NaN
#
# [69875 rows x 8 columns]

# %%
df.agency_name.unique()
# Out:
# array(['maricopa county sheriffs office', 'pima law enforcement services',
#        'maricopa county parks and recreation',
#        'phoenix police department', 'pinal county sheriffs office',
#        'oro valley police department', 'tucson police department',
#        'goodyear police department',
#        'arizona department of public safety', 'eagar police department',
#        'chino valley police department', 'tolleson police department',
#        'avondale police department', 'scottsdale police department',
#        'arizona department of transportation - ecd',
#        'navajo county sheriffs office', 'pima county sheriffs department',
#        'university of arizona police department',
#        'tempe police department', 'huachuca city police department',
#        'cochise county sheriffs office', 'chandler police department',
#        'ak chin tribal police', 'eloy police department',
#        'gilbert police department', 'yuma police department',
#        'yuma county sheriffs office', 'yavapai county sheriffs office',
#        'clarkdale police department', 'camp verde marshals office',
#        'pima county attorneys office', 'mesa police department',
#        'central arizona college police department',
#        'bisbee police department', 'cocopah tribal police department',
#        'el mirage police department', 'maricopa county attorneys office',
#        'flagstaff police department',
#        'pima comm coll department of public safety',
#        'tucson airport authority police department',
#        'surprise police department', 'arizona attorney generals office',
#        'glendale police department', 'sierra vista police department',
#        'coconino county sheriffs office',
#        'apache junction police department',
#        'salt river pima-maricopa indian communit',
#        'kingman police department', 'sedona police department',
#        'arizona department of racing - investigation',
#        'tombstone marshals office', 'jerome police department',
#        'sahuarita police department', 'peoria police department',
#        'gila county sheriffs office', 'navajo division of public safety',
#        'cottonwood police department',
#        'northern arizona university police department',
#        'holbrook police department', 'patagonia marshals office',
#        'mohave county sheriffs office', 'payson police department',
#        'paradise valley police department',
#        'lake havasu city police department', 'arizona state parks',
#        'fountain hills marshalls office',
#        'arizona state university police department',
#        'globe police department', 'la paz county sheriffs office',
#        'arizona game and fish department', 'douglas police department',
#        'bullhead city police department', 'prescott police department',
#        'phoenix fire department', 'mesa fire department',
#        'miami police department', 'benson police department',
#        'hayden police department', 'quartzsite police department',
#        'coolidge police department', 'buckeye police department',
#        'arizona department of liquor licenses and control',
#        'mammoth police department', 'pima county park police',
#        'nogales police department',
#        'arizona department of corrections, rehabilitation and reentry',
#        'south tucson department of public safety',
#        'prescott valley police department', 'page police department',
#        'arizona western college police department',
#        'superior police department',
#        'arizona department of administration - capito',
#        'wickenburg police department', 'greenlee county sheriffs office',
#        'casa grande police department', 'pascua yaqui police department',
#        'arizona corporation commission - securities d',
#        'youngtown police department', 'williams police department',
#        'tohono oodham police department',
#        'springerville police department', 'florence police department',
#        'san luis police department', 'kearny police department',
#        'safford police department',
#        'grand canyon university police department',
#        'apache county sheriffs office',
#        'yavapai community college police department',
#        'arizona department of economic security - osi',
#        'clifton police department',
#        'arizona department of gaming - investigation',
#        'willcox department of public safety',
#        'santa cruz county sheriffs office',
#        'arizona department of agriculture - animal services',
#        'show low police department', 'arizona drug control district',
#        'marana police department', 'gila river police department',
#        'wellton police department', 'guadalupe police department',
#        'maricopa community college district', 'duncan police department',
#        'whitemountain apache police department',
#        'union pacific railroad police department', 'mohave county parks',
#        'arizona department of revenue', 'graham county sheriffs office',
#        'ft mcdowell tribal police department',
#        'maricopa police department', 'somerton police department',
#        'parker police department',
#        'maricopa county constable - central phx jp',
#        'central arizona water conservation district',
#        'snowflake - taylor police department', 'us bia papago - sells',
#        'cave creek marshals office',
#        'pinetop - lakeside police department',
#        'winslow police department',
#        'colorado river indian tribe police department',
#        'gila county attorneys office', 'st. johns police department',
#        'arizona criminal intelligency system age',
#        'arizona department of insurance',
#        'yavapai county attorneys office',
#        'arizona lottery commission - security section',
#        'pinal county attorneys office',
#        'san carlos recreation and wildlife',
#        'yuma county constables office', 'fredonia marshals office',
#        'san carlos tribal police department',
#        'navajo county attorneys office',
#        'arizona department of juvenile corrections',
#        'burlington no. santa fe railroad police',
#        'yavapai-prescott indian police departmen',
#        'eastern arizona college police department',
#        'tonto apache tribal police department',
#        'yavapai-apache nation police department',
#        'la paz county certified ranger division',
#        'graham county attorneys office',
#        'ft mojave tribal police department',
#        'la paz county attorneys office', 'navajo county parks department',
#        'arizona state university dps west', 'williams justice court',
#        'hopi resource enforcement services',
#        'hualapai nation police department', 'carefree marshals office',
#        'bia - hopi indian agency', 'yuma county attorneys office',
#        'thatcher police department', 'queen creek police department',
#        'flagstaff justice court', 'payson regional constable',
#        "tohono o'odham ofc of prosecutor", 'us bia san carlos agency',
#        'cochise county attorneys office',
#        'colorado city police department', 'pima police  department',
#        'dine college police department',
#        'greenlee county attorneys office',
#        'whitemountain apache wildlife and outdoor',
#        'arizona state univeristy dps east',
#        'santa cruz county attorneys office',
#        'coconino county attorneys office',
#        'arizona department of revenue, tucson',
#        'gila county constable - globe precinct',
#        'arizona department of child safety',
#        'gila river indian community rangers',
#        'yavapai county constables office - verde valley pre',
#        'quechan tribal police department',
#        'arizona comm agriculture- horticulture',
#        'pinal county constable - precinct 7',
#        'mohave county attorneys office',
#        'navajo epa-environmental law enforcement department',
#        'colorado river indian tribe department of fish',
#        'fredonia police department',
#        'yavapai county constables office - prescott precinct',
#        'round valley police department'], dtype=object)

# %%
df.to_csv("../data/output/arizona_index.csv", index=False)
