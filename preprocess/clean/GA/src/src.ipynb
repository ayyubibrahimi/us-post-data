# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../data/output/georgia_index.csv")

    df = df.rename(columns={"agcy_name": "agency_name"})
    return df


df = read_tbl()

df


# with gzip.open("../data/output/georgia-processed.csv.gz", 'wt') as f:
#     df.to_csv(f, index=False)
# Out:
#        person_nbr        full_name                     employment_status  \
# 0         O246465     AAMIR WISHAH  ACTIVELY EMPLOYED IN LAW ENFORCEMENT
# 1         O095227  AANERUD H DAMON                 VOLUNTARY RESIGNATION
# 2         O095227  AANERUD H DAMON                 VOLUNTARY RESIGNATION
# 3         O095227  AANERUD H DAMON               RANK CHANGE - PROMOTION
# 4         O095227  AANERUD H DAMON  ACTIVELY EMPLOYED IN LAW ENFORCEMENT
# ...           ...              ...                                   ...
# 134658    O136250  ZYDONYK L ASHBY               RANK CHANGE - PROMOTION
# 134659    O136250  ZYDONYK L ASHBY  ACTIVELY EMPLOYED IN LAW ENFORCEMENT
# 134660    O110791  ZYGAJ M STEPHEN               RANK CHANGE - PROMOTION
# 134661    O110791  ZYGAJ M STEPHEN               RANK CHANGE - PROMOTION
# 134662    O110791  ZYGAJ M STEPHEN  ACTIVELY EMPLOYED IN LAW ENFORCEMENT
#
#         start_date    end_date first_name middle_name last_name suffix  \
# ...

# %%
df.to_csv("../../../../download/data/georgia/georgia_index.csv", index=False)
