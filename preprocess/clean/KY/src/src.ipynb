# %%
import re
from datetime import datetime

import numpy as np
import pandas as pd

# %%
def clean_agency(df):
    df.loc[:, "agency_name"] = df.agency_name.str.replace(
        r"P\.D\.", "Police Department", regex=True
    )
    return df


def convert_date(date_value):
    if pd.isna(date_value):
        return np.nan

    try:
        date_str = str(date_value)
        date_obj = datetime.strptime(date_str, "%m/%d/%y")
        return date_obj.strftime("%Y-%m-%d")
    except ValueError:
        print(f"Warning: Could not convert date '{date_value}'")
        return np.nan


def clean_dates(df):
    df["start_date"] = df["start_date"].apply(convert_date)
    df["end_date"] = df["end_date"].apply(convert_date)
    return df


def split_names(df):
    names = df["full_name"].str.extract(r"(\w+),\s+(\w+)\s*(.+)?")

    df["last_name"] = names[0]
    df["first_name"] = names[1]

    suffixes = r"\b(Jr\.?|Sr\.?|I{2,3}|IV)\b"

    def split_rest(rest):
        if pd.isna(rest):
            return pd.Series({"middle_name": "", "suffix": ""})

        # Check for suffix first
        suffix_match = re.search(suffixes, rest)
        if suffix_match:
            suffix = suffix_match.group()
            # Remove suffix from rest
            rest = re.sub(suffixes, "", rest).strip()
            # If anything remains, it's the middle name
            middle_name = rest if rest else ""
        else:
            suffix = ""
            middle_name = rest.strip() if rest.strip() else ""

        return pd.Series({"middle_name": middle_name, "suffix": suffix})

    # Apply the split_rest function
    rest_split = names[2].apply(split_rest)

    df["middle_name"] = rest_split["middle_name"]
    df["suffix"] = rest_split["suffix"]

    return df


def read_tbl():
    df = pd.read_csv("../../../../data/KY/2022-10-13/ky-employment-history.csv")
    df = df.rename(
        columns={
            "FULL_NAME": "full_name",
            "gender": "sex",
            "Certification": "certification",
            "Certification Status": "certification_status",
            "Acadmey Id": "academy_id",
            "Pops Certification Number": "person_nbr",
            "YearOfBirth": "year_of_birth",
            "Employing Agency": "agency_name",
            "Employment Title": "rank",
            "Employment Hire Date": "start_date",
            "Employment End Date": "end_date",
        }
    )
    return df


df = read_tbl()

df = df.pipe(clean_agency).pipe(clean_dates).pipe(split_names)

df
# df.to_csv("../data/output/kentucky_index.csv", index=False)
# Out:
#                full_name Gender       certification certification_status  \
# 0           Abbott, Eric   Male  POPS Certification            Certified
# 1       Abbott, Robert E   Male  POPS Certification            Certified
# 2         Abell, Brian P   Male  POPS Certification            Certified
# 3         Abell, Brian P   Male  POPS Certification            Certified
# 4         Abell, Brian P   Male  POPS Certification            Certified
# ...                  ...    ...                 ...                  ...
# 15803    Zummach, Daniel   Male  POPS Certification            Certified
# 15804      Zuniga, Larry   Male  POPS Certification            Certified
# 15805      Zuniga, Larry   Male  POPS Certification            Certified
# 15806    Zuniga, Ricardo   Male  POPS Certification               Active
# 15807  Zurborg, Brian E.   Male  POPS Certification            Certified
#
#       academy_id person_nbr  year_of_birth  \
# 0      0951-7824      19775         1988.0
# 1      9734-4568      18632         1988.0
# 2      2182-9309  2182-9309         1995.0
# 3      2182-9309  2182-9309         1995.0
# 4      2182-9309  2182-9309         1995.0
# ...          ...        ...            ...
# 15803  5490-5848      16467         1983.0
# 15804  0383-7922      17396         1987.0
# 15805  0383-7922      17396         1987.0
# 15806  9815-1334  9815-1334         1983.0
# 15807  4079-4412       3955         1972.0
#
#                               agency_name      rank  start_date    end_date  \
# 0               Paducah Police Department   Officer  2016-03-31         NaN
# 1                     Fayette Co. Sheriff  Sergeant  2011-09-01         NaN
# 2             Bardstown Police Department   Officer  2022-05-02         NaN
# 3               Lebanon Police Department   Officer  2020-10-14  2022-05-02
# 4           Springfield Police Department   Officer  2017-10-29  2020-10-12
# ...                                   ...       ...         ...         ...
# 15803  Louisville Metro Police Department   Officer  2010-11-08         NaN
# 15804     Bowling Green Police Department   Officer  2011-10-03  2020-03-13
# 15805     Bowling Green Police Department   Officer  2021-07-12         NaN
# 15806  Louisville Metro Police Department   Officer  2022-02-21         NaN
# 15807          Edgewood Police Department     Chief  1996-10-01         NaN
#
#       last_name first_name middle_name suffix
# 0        Abbott       Eric
# 1        Abbott     Robert           E
# 2         Abell      Brian           P
# 3         Abell      Brian           P
# 4         Abell      Brian           P
# ...         ...        ...         ...    ...
# 15803   Zummach     Daniel
# 15804    Zuniga      Larry
# 15805    Zuniga      Larry
# 15806    Zuniga    Ricardo
# 15807   Zurborg      Brian          E.
#
# [15808 rows x 15 columns]

# %%
df.agency_name.unique()
# Out:
# array(['Paducah Police Department', 'Fayette Co. Sheriff',
#        'Bardstown Police Department', 'Lebanon Police Department',
#        'Springfield Police Department', 'Audubon Park Police Department',
#        'Louisville Metro Police Department', 'Marion Co. Sheriff',
#        'Cumberland Co. Sheriff', 'Burkesville Police Department',
#        'Commercial Vehicle Enforcement', 'Lexington Police Department',
#        'Harlan Co. Sheriff', 'KSP Academy', 'Erlanger Police Department',
#        'KY Dept. of Fish & Wildlife', 'Franklin Co. Sheriff',
#        'Frankfort Police Department',
#        'Cincinnati/N. KY Airport Police Department', 'Laurel Co. Sheriff',
#        'Oldham Co. Sheriff', 'Daviess Co. Sheriff',
#        'KY Office of Charitable Gaming', 'Trigg Co. Sheriff',
#        'Cadiz Police Department', 'Cold Spring Police Department',
#        'Pendleton Co. Sheriff', 'Military Leave', 'Nelson Co. Sheriff',
#        'Danville Police Department', 'Mayfield Police Department',
#        'Magoffin Co. Sheriff', 'Salyersville Police Department',
#        'Univ. of KY Police Department', 'Carlisle Police Department',
#        'Maysville Police Department', 'Millersburg Police Department',
#        'Nicholas Co. Sheriff', 'Franklin Police Department',
#        'Bowling Green Police Department', 'Oak Grove Police Department',
#        'Owingsville Police Department', 'Bath Co. Sheriff',
#        'Mt. Sterling Police Department', 'Montgomery Co. Sheriff',
#        'LaGrange Police Department', 'Morehead Police Department',
#        'Lynch Police Department', 'Kenton Co. Sheriff',
#        'Ludlow Police Department', 'Crescent Springs Police Department',
#        'Independence Police Department', 'Muhlenberg Co. Sheriff',
#        'Central City Police Department', 'Greenville Police Department',
#        'Fulton Police Department', 'Stanford Police Department',
#        'Paris Police Department', 'Bourbon Co. Sheriff',
#        'Georgetown Police Department', 'Lyon Co. Sheriff',
#        'Boone Co. Sheriff', 'Boone Co. Police Department',
#        'Allen Co. Sheriff', 'Owensboro Police Department',
#        'Beattyville Police Department', 'Owsley Co. Sheriff',
#        'Harrodsburg Police Department', 'Boyle Co. Sheriff',
#        'Hillview Police Department', 'McLean Co. Sheriff',
#        'Providence Police Department', 'Pike Co. Sheriff',
#        'Pikeville Police Department', 'Louisa Police Department',
#        'Jefferson Co. Sheriff', 'Morgan Co. Sheriff',
#        'West Liberty Police Department', 'Covington Police Department',
#        'KY Dept. of Parks - Ranger Division', 'Barren Co. Sheriff',
#        'Marion Police Department', 'Crittenden Co. Sheriff',
#        'Univ. of Louisville Police Department', 'Hardin Co. Sheriff',
#        'Hopkinsville Police Department', 'Shelbyville Police Department',
#        'Cumberland Police Department', 'Catlettsburg Police Department',
#        'Boyd Co. Sheriff', 'Princeton Police Department',
#        'Dawson Springs Police Department', 'Owenton Police Department',
#        'Gallatin Co. Sheriff', 'Edgewood Police Department',
#        'Oldham Co. Police Department', 'Indian Hills Police Department',
#        'Richmond Police Department', 'Kenton Co. Police Department',
#        'Somerset Police Department', 'Pulaski Co. Sheriff',
#        'Butler Co. Sheriff', 'Harlan Police Department',
#        'Loyall Police Department', 'Barbourville Police Department',
#        'Knox Co. Sheriff', 'Lynnview Police Department',
#        'Shepherdsville Police Department', 'Bullitt Co. Sheriff',
#        'Northern KY Univ. Police Department',
#        'Villa Hills Police Department', 'Beaver Dam Police Department',
#        'Shively Police Department', 'Anchorage Police Department',
#        'Florence Police Department', 'Williamsburg Police Department',
#        'Madison Co. Sheriff', 'Dept. of Criminal Justice Training',
#        'Worthington Police Department', 'Olive Hill Police Department',
#        'Carter Co. Sheriff', 'Ashland Police Department',
#        'Eddyville Police Department',
#        'Nicholas Co. School Police Department',
#        'Lewisburg Police Department', 'Wilmore Police Department',
#        'Lakeside Park/Crestview Hills Police Department',
#        'Fulton Co. Sheriff', 'Hickman Co. Sheriff',
#        'Clinton Police Department', 'Graves Co. Sheriff',
#        'Hickman Police Department', 'Calloway Co. Sheriff',
#        'Garrard Co. Sheriff', 'Morgantown Police Department',
#        'London Police Department', 'KSP Post 11, London',
#        'Russellville Police Department', 'Marshall Co. Sheriff',
#        'Western KY Univ. Police Department',
#        'Clark Co. Schools Police Department', 'Paris/Bourbon Co. 911',
#        'Eastern KY Univ. Police Department', 'Warren Co. Sheriff',
#        'Glasgow Police Department', 'McCracken Co. Sheriff',
#        'Ft. Mitchell Police Department', 'Prestonsburg Police Department',
#        'Johnson Co. Sheriff', 'Ft. Thomas Police Department',
#        'Newport Police Department', 'St. Matthews Police Department',
#        'Anderson Co. Sheriff', 'Blue Grass Airport Dept of Public Safety',
#        'Stamping Ground Police Department', 'Jessamine Co. Sheriff',
#        'Clay Co. Sheriff', 'Lyndon Police Dept',
#        'Jefferson Co. Schools Police Department', 'Union Co. Sheriff',
#        'Fayette Co. Schools Police Dept', 'Hopkins Co. Sheriff',
#        'Ft. Wright Police Department', 'Falmouth Police Department',
#        'Clinton Co. Sheriff', 'Monticello Police Department',
#        'Louisville Regional Airport Police Department',
#        'Winchester Police Department', 'Livingston Police Department',
#        'Rockcastle Co. Sheriff', 'Mt. Vernon Police Department',
#        'Lawrenceburg Police Department', 'Munfordville Police Department',
#        'Liberty Police Department', 'Scottsville Police Department',
#        'Mt. Washington Police Department', 'McCracken Co. Constable',
#        'Tompkinsville Police Department', 'Hart Co. Sheriff',
#        'Brownsville Police Department', 'Hodgenville Police Department',
#        'Cave City Police Department',
#        'Metcalfe County Schools Police Dept.',
#        'Edmonton Police Department',
#        'KY Div. of Animal Health/Field Enf.',
#        'Louisville Metro Corrections', 'Middlesboro Police Department',
#        'Christian Co. Sheriff', 'Powell Co. Sheriff',
#        'Livingston Co. Sheriff', 'Calvert City Police Department',
#        'West Buechel Police Department', 'Attorney Generals Office',
#        'KY Alcoholic Beverage Control', 'Evarts Police Department',
#        'Murray Police Department', 'Murray State Univ. Police Department',
#        'Henry Co. Sheriff', 'Eminence Police Department',
#        'Campbellsville Police Department',
#        'Taylor Mill Police Department', 'Hyden Police Department',
#        'Leslie Co. Sheriff', 'Burgin Police Department',
#        'Nicholasville Police Department', 'Hazard Police Department',
#        'Corbin Police Department', 'Whitley Co. Sheriff',
#        'KY Horse Park Police Department', 'Rockcastle Co. 911',
#        'Dayton Police Department', 'Cynthiana Police Department',
#        'Harrison Co. Sheriff', 'Irvington Police Department',
#        'Hardinsburg Police Department', 'Perry Co. Sheriff',
#        'McCracken Co. Public Schools Police Department',
#        'Ft. Knox Emergency Services - Law Enforcement Division',
#        'Bell Co. Sheriff', 'Henderson Police Department',
#        'Breckinridge Co. Sheriff', 'Berea Police Department',
#        'Madisonville Police Department', 'Monroe Co. Sheriff',
#        'KSP Post 15, Columbia', 'Wayne Co. Sheriff',
#        'Bell County Board of Education',
#        'Montgomery Co. School Dist. Police',
#        'Strathmoor Village Police Department', 'KSP Facilities Security',
#        'Radcliff Police Department', 'Bellevue Police Department',
#        'Middletown Police Department', 'Letcher Co. Sheriff',
#        'Simpson Co. Sheriff', 'Powderly Police Department',
#        'Clay Police Department', 'Madison Co. E-911',
#        'Russell Springs Police Department',
#        'Lebanon Junction Police Department',
#        'KY State Univ. Police Department',
#        'Hurstbourne Acres Police Department',
#        'Jeffersontown Police Department', 'Greenup Co. Sheriff',
#        'Greenup Co. 911', 'Bellefonte Police Department',
#        'Menifee Co. Sheriff', 'Grayson Co. Sheriff', 'Ohio Co. Sheriff',
#        'Washington Co. Sheriff', 'Jefferson Co. Police Department',
#        'Shelby Co. Sheriff', 'Scott Co. Sheriff',
#        'Elizabethtown Police Department', 'Albany Police Department',
#        'Grayson Police Department', 'Larue Co. Sheriff', 'Hardin Co. 911',
#        'Henderson Co. Sheriff', 'Mortons Gap Police Department',
#        'Taylor Co. Sheriff', 'Spencer Co. Sheriff',
#        'Simpsonville Police Department', 'Webster Co. Sheriff',
#        'Jackson Co PD', 'Jackson Co. Sheriff',
#        'Taylorsville Police Department', 'Guthrie Police Department',
#        'Elkton Police Department', 'Russell Co. Sheriff',
#        'KSP Post 5, Campbellsburg', 'Owen Co. Sheriff',
#        'Smiths Grove Police Department', 'Police Corps',
#        'Mason Co. Sheriff', 'Vanceburg Police Department',
#        'Floyd Co. Sheriff', 'Highland Heights Southgate Police Auth.',
#        'Campbell Co. Police Department',
#        'Highland Heights Police Department',
#        'Whitley Co. Communications Ctr.', 'Lewis Co. Sheriff',
#        'Muhlenberg Co. Police Department', 'Augusta Police Department',
#        'Manchester Police Department', 'Sadieville Police Department',
#        'Knott Co. Sheriff', 'Whitesburg Police Department',
#        'London/Laurel Co. Comm. Ctr.', 'Carrollton Police Department',
#        'Carroll Co. Sheriff', 'Williamstown Police Department',
#        'Versailles Police Department', 'Warsaw Police Department',
#        'Bracken Co. Sheriff', 'Fleming-Neon Police Department',
#        'Jenkins Police Department', 'Louisville Alcohol Beverage Control',
#        'Morehead State Univ. Police Department', 'Lawrence Co. Sheriff',
#        'Martin Co. Sheriff', 'Flemingsburg Police Department',
#        'Wolfe Co. Sheriff', 'Southgate Police Department',
#        'Ferguson Police Department', 'Sebree Police Department',
#        'McCreary County Board of Education', 'McCreary Co. Sheriff',
#        'Bullitt Co. Dispatch', 'Adair Co. Sheriff',
#        'Columbia Police Department', 'Elliott Co. Sheriff',
#        'Irvine Police Department', 'Alexandria Police Department',
#        'KSP Post 10, Harlan', 'Logan Co. Sheriff',
#        'KSP Post 2, Madisonville', 'Heritage Creek Police Department',
#        'Muldraugh Police Department', 'Grant Co. Sheriff',
#        'Robertson County Schools', 'Leitchfield Police Department',
#        'Clark Co. Sheriff', 'Edmonson Co. Sheriff',
#        'Pineville Police Department', 'Todd Co. Sheriff',
#        'Fountain Run Police Department', 'Burnside Police Department',
#        'Jefferson Co. Attorney', 'Hartford Police Department',
#        'Benton Police Department', 'Mercer Co. Sheriff',
#        'Casey Co. Sheriff', 'Prospect Police Department', 'Clay Co. 911',
#        'Raceland Police Department', 'South Shore Police Department',
#        'Barren-Metcalfe ECC', 'Gallatin Co. Dispatch',
#        'Jamestown Police Department', 'Whitley Co. Police Department',
#        'Woodford Co. Police Department', 'Trigg Co. E-911',
#        'Paintsville Police Department', 'Hollow Creek Police Department',
#        'Uniontown Police Department', 'Elsmere Police Department',
#        'Logan Co. E.C.C.', 'KSP Post 6, Dry Ridge', 'Hancock Co. Sheriff',
#        'Elkhorn City Police Department', 'Rowan Co. Sheriff',
#        'Fleming Co. Sheriff', 'Martin Police Department',
#        'Perry Co. Police Department', 'Ballard Co. Sheriff',
#        'Kenton Co. Emergency Communications',
#        'Lancaster Police Department', 'Garrard County Police Department',
#        'Glencoe Police Department', 'Jessamine Co. 911',
#        'Wheelwright Police Department', 'Ballard Co. 911',
#        'Union Co. Coroner', 'Morganfield Police Department',
#        'KSP Post 12, Frankfort', 'Ins. Fraud-KY Public Prot./Reg.',
#        'Pioneer Village Police Department', 'Lone Oak Police Department',
#        'Flatwoods Police Department', 'M2LE',
#        'Knott Co. Police Department',
#        'Graves Co. Schools Police Department', 'Woodford Co. Sheriff',
#        'Jackson Police Department', 'McCreary Co. 911',
#        'Campbell Co. Sheriff', 'Woodburn Police Department',
#        'Horse Cave Police Department', 'Brandenburg Police Department',
#        'Caneyville Police Department', 'Clarkson Police Department',
#        'Trigg County Police Department', 'Knox Co 911 Dispatch Center',
#        'Lincoln Co. Sheriff', 'Greensburg Police Department',
#        'Marshall Co. E-911', 'Woodford Co. Public Schools',
#        'KSP Post 9, Pikeville', 'Trimble Co. Sheriff',
#        'Wilder Police Department', 'Bardwell Police Department',
#        'Stanton Police Department',
#        'Jenkins Independent Schools Police Dept.', 'Meade Co. Sheriff',
#        'Coal Run Village Police Department',
#        'Taylor County Board of Education', 'Benham Police Department',
#        'Bowling Green Fire Department', 'KSP Post 1 , Mayfield',
#        'Menifee Co. 911', 'KSP Post 3, Bowling Green',
#        'McCracken Co. Coroner', 'New Castle Police Department',
#        'Louisville Metro Safe', 'Russell Police Department',
#        'KSP Post 7, Richmond', 'KSP Criminal  ID & Records',
#        'KSP Post 4, Elizabethtown', 'Lincolnshire Police Department',
#        'West Point Police Department', 'Pennyrile Narcotics Task Force',
#        'Northfield Police Department', 'Vine Grove Police Department',
#        'Paducah Public Schools Police Department',
#        'AOC - Pretrial Services', 'Transylvania Univ. Police Department',
#        'Gamaliel Police Department', 'Park Hills Police Department',
#        'Dry Ridge Police Department', 'Laurel Co 5th Dist Constable',
#        'Caldwell Co. Sheriff', 'Science Hill Police Department',
#        'Brooksville Police Department', 'KSP Post 8, Morehead',
#        'Lee County 911', 'Lee Co. Sheriff', 'Eubank Police Department',
#        'City of Paducah 911', 'KSP DESI - West',
#        'Boone Co. Public Safety Center', 'Martin Co.  911',
#        'McKee Police Department',
#        'Dept of Military Affairs - Facilites Div',
#        'Auburn Police Department', 'Oldham Co. Dispatch',
#        'Meadow Vale Police Department', 'Earlington Police Department',
#        'Brodhead Police Department', 'Grayson Co. 911',
#        'Clay City Police Department', 'Sparta Police Department',
#        'Breathitt Co. Sheriff', 'Crab Orchard Police Department',
#        'Lewisport Police Department', 'Pippa Passes Police Department',
#        'Middlesboro Independent Schools', 'Carlisle Co. Sheriff',
#        'Bloomfield Police Department', 'Junction City Police Department',
#        'Campbell Co. Dispatch', 'Northern Ky Drug Strike Force',
#        'Bradfordsville Police Department', 'Robertson Co. Sheriff',
#        'Daviess Co. Public Schools Police Dept.',
#        'Barkley Regional Airport', 'LaCenter Police Department',
#        'Bourbon Co. Schools Police', 'Nelson Co. Police Department',
#        'Sturgis Police Department', 'Mason Co. Detention Center',
#        'Greenup Police Department', 'KSP Post 13, Hazard',
#        'Louisville Metro Youth Detention Service',
#        'Butler Police Department', 'Boyd Co. Police Department',
#        'Trenton Police Department',
#        'Clinton Co. Schools Police Department', 'Louisville Arson & Fire',
#        'Pineville Independent Board of Education', 'Bell Co. Dispatch',
#        'Muhlenberg Co. 911', 'Perryville Police Department',
#        'Centertown Police Department', 'KSP Post 14, Ashland',
#        'Cloverport Police Department', 'Metcalfe Co. Sheriff',
#        'Nelson County E-911', 'New Haven Police Department',
#        'Silver Grove Police Department', 'Pewee Valley Police Department',
#        'Campbellsville Independent Schools Police Dept.',
#        'Campbellsville 911 Comm.', 'Perry Co. 911',
#        'Monticello/Wayne Co.  911', 'Green Co. Sheriff',
#        'Mt. Olivet Police Department',
#        'Pikeville Independent Schools Police Dept',
#        'Frankfort/Franklin Co. 911', 'Estill Co. Sheriff',
#        'Commonwealth Attorney - 16th Circuit',
#        'Woodlawn Park Police Department',
#        'Commonwealth Attorney - 37th Circuit', 'Boyd Co. PSCC 911',
#        'Jackson Co Fiscal Court', 'Wayland Police Department',
#        'Commonwealth Attorney - 26th Circuit', 'Pulaski Co. Police Dept',
#        'KSP Central Laboratory', 'Bluegrass 911 Central Communications',
#        'Ravenna Police Department', 'Edmonson Co. Constable - District 5',
#        'Letcher Co. Police Department', 'Christian Co. Police Department',
#        'Butler Co. Dispatch E-911', 'Walton Police Department',
#        'Powell Co. Dispatch', 'Bancroft Police Department',
#        'Campbellsburg Police Department', 'Crofton Police Department',
#        'Pennyrile Emergency 911', 'Hawesville Police Department',
#        'Annville Police Department', 'Jefferson Co. Coroner',
#        'Cumberland County School District Police', 'Hart Co. 911',
#        'Adairville Police Department', 'Pembroke Police Department',
#        'Larue Co. 911', 'Rockcastle County Attorneys Office',
#        'Bardstown City Schools Law Enforcement Services',
#        'Booneville Police Department', 'KSP Properties Management',
#        'Hickman Co Schools PD', 'Clinton Co. Emergency Services',
#        'Russell Co. Dispatch', 'Anderson Co. Constable - District 4',
#        'Blue Grass Railroad Police', 'U.S. Forest Service - DBNF',
#        'Cumberland County Alcohol Beverage Control',
#        'Pleasureville Police Department', 'Bath Co. 911',
#        'Anderson Co. Police Department', 'Cynthiana - Harrison Co. E-911',
#        'Louisville Housing Authority Police Department',
#        'Morgan County Board of Education',
#        'Commonwealth Attorney - Warren Co', 'Marshall Co. Coroner',
#        'Hustonville Police Department',
#        'Commonwealth Attorney - 28th Circuit', 'KSP DESI - East',
#        'Lawrence Co. 911', 'Lawrence Co Constable - District 2',
#        'Inez Police Department', 'McLean Co. Dispatch',
#        'Lexington Enhanced 911', 'Shelby Co. 911 Communications'],
#       dtype=object)
