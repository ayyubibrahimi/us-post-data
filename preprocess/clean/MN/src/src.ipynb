# %%
import pandas as pd

def read_tbl():
    df = pd.read_excel("../../../../data/MN/2024-8-28/Officer-with-Agency-Data-2024-08-27-15-32-44-1.xlsx", nrows=100)
    return df 

def remove_first_column(df):
    df = df.iloc[:, 1:]
    return df


def propagate_uids(df):
    result_df = df.copy()
    
    # Initialize variables to track current person
    current_uid = None
    current_person_rows = []
    
    # Process rows sequentially
    processed_rows = []
    
    for idx, row in result_df.iterrows():
        # Check if this is a subtotal row (has 'Subtotal' in last_name)
        if isinstance(row['last_name'], str) and 'Subtotal' in row['last_name']:
            # Process accumulated rows for the previous person
            if current_person_rows:
                processed_rows.extend(current_person_rows)
            
            # Reset tracking variables
            current_uid = None
            current_person_rows = []
            
            # Add the subtotal row
            processed_rows.append(row.to_dict())
            
        else:
            # If this row has a non-NaN UID, store it as the current UID
            if pd.notna(row['uid']):
                current_uid = row['uid']
            
            # Create a copy of the row and update its UID
            row_dict = row.to_dict()
            if current_uid is not None:
                row_dict['uid'] = current_uid
            
            # Add this row to the current person's rows
            current_person_rows.append(row_dict)
    
    # Process the last person's rows if any remain
    if current_person_rows:
        processed_rows.extend(current_person_rows)
    
    # Convert processed rows back to DataFrame
    result_df = pd.DataFrame(processed_rows)
    
    # Ensure numeric UIDs where possible
    result_df['uid'] = pd.to_numeric(result_df['uid'], errors='ignore')
    
    return result_df


df = read_tbl()

df = df.rename(columns={"Unnamed: 1": "uid", 
                        "Unnamed: 3": "last_name", 
                        "Unnamed: 4": "first_name", 
                        "Unnamed: 5": "middle_name", 
                        "Unnamed: 6": "agency_name",
                        "Unnamed: 7": "status",
                        "Unnamed: 8": "start_date",
                        "Unnamed: 9": "agency_status",
                        "Unnamed: 10": "end_date"})

def remove_first_8_rows(df):
    df = df.iloc[9:]
    return df

def drop_empty_rows(df):
    return df[~((df.uid == "Subtotal"))]

df = df.pipe(remove_first_column).pipe(propagate_uids).pipe(remove_first_8_rows).pipe(drop_empty_rows)

df = df.drop(columns=["Unnamed: 2"])



df.head(20)
# Out:
#       uid    last_name first_name middle_name  \
# 9       1     Andersen     Steven       Peder
# 10      1     Andersen     Steven       Peder
# 11      1     Andersen     Steven       Peder
# 12      1     Andersen     Steven       Peder
# 14     10         Dahl       Gary   Frederick
# 16    100        Barth      James  Stansberry
# 18   1000        Salto     Norman        Dean
# 20  10000     Amendola     Thomas     Richard
# 22  10006  Franckowiak     George     Isadore
# 24  10008       Graves      James     Stephen
# 26   1001     Eckhardt      Loren        Wynn
# 28  10014      Koopman      Garry         Lee
# 30  10015          Lee      Kraig    Clarence
# 32  10017     Lundgren     Jerold     Charles
# 34  10022     Rovinsky      Bruce     William
# 35  10022     Rovinsky      Bruce     William
# 37  10025     Rudnicki     Arthur     Stanley
# 39  10027         Shaw     Ronald      Thomas
# 41  10029      Staples       Gary      Howard
# 43  10030        Stute    William   Frederick
#
#                              agency_name      status start_date agency_status  \
# 9                  Verndale Police Dept.  Terminated  7/15/1973        Former
# 10          Beltrami Co. Sheriffs Office  Terminated   5/1/1994        Former
# 11  DPS, Bureau Of Criminal Apprehension  Terminated   7/1/1978        Former
# 12                  Menahga Police Dept.  Terminated  4/15/1994        Former
# 14  DPS, Bureau Of Criminal Apprehension  Terminated   7/1/1978        Former
# 16                Minnesota State Patrol  Terminated   7/1/1978        Former
# 18           Douglas Co. Sheriffs Office  Terminated  9/15/2013        Former
# 20         Canosia Township Police Dept.  Terminated   3/9/1983        Former
# 22                       Gnesen Township  Terminated  5/20/1988        Former
# 24               Fredenberg Police Dept.  Terminated  5/20/1988        Former
# 26         Faribault Co. Sheriffs Office  Terminated   7/1/1978        Former
# 28                  Scanlon Police Dept.  Terminated  8/19/1997        Former
# 30         St. Louis Co. Sheriffs Office  Terminated  5/20/1988        Former
# 32         Canosia Township Police Dept.  Terminated  3/19/1982        Former
# 34                Arlington Police Dept.  Terminated   7/1/2000        Former
# 35                Arlington Police Dept.  Terminated   7/1/2000        Former
# 37                      Thomson Township  Terminated  8/19/1997        Former
# 39                       Gnesen Township  Terminated  5/20/1988        Former
# 41                      Clinton Township  Terminated  5/20/1988        Former
# 43        Washington Co. Sheriffs Office  Terminated  5/20/1988        Former
#
#       end_date
# 9    4/16/1996
# 10   4/27/2007
# 11    1/1/1980
# 12    3/1/1995
# 14   6/30/1998
# 16    7/7/1998
# 18   9/16/2013
# 20    1/1/2000
# 22   6/30/2004
# 24   1/31/2000
# 26    2/9/2007
# 28   2/13/2002
# 30    3/8/1999
# 32  12/18/1997
# 34    6/1/2014
# 35   3/13/2017
# 37   5/16/2005
# 39    7/1/1997
# 41    6/6/2002
# 43   1/31/2013

# %%
df
# Out:
#       uid    last_name   first_name middle_name  \
# 9       1     Andersen       Steven       Peder
# 10      1     Andersen       Steven       Peder
# 11      1     Andersen       Steven       Peder
# 12      1     Andersen       Steven       Peder
# 14     10         Dahl         Gary   Frederick
# 16    100        Barth        James  Stansberry
# 18   1000        Salto       Norman        Dean
# 20  10000     Amendola       Thomas     Richard
# 22  10006  Franckowiak       George     Isadore
# 24  10008       Graves        James     Stephen
# 26   1001     Eckhardt        Loren        Wynn
# 28  10014      Koopman        Garry         Lee
# 30  10015          Lee        Kraig    Clarence
# 32  10017     Lundgren       Jerold     Charles
# 34  10022     Rovinsky        Bruce     William
# 35  10022     Rovinsky        Bruce     William
# 37  10025     Rudnicki       Arthur     Stanley
# 39  10027         Shaw       Ronald      Thomas
# 41  10029      Staples         Gary      Howard
# 43  10030        Stute      William   Frederick
# 45  10032      Thurmer       Norman      Joseph
# 47  10033         Zink          Jay     Neville
# 49  10034       Cordie       Joseph    Nicholas
# 50  10034       Cordie       Joseph    Nicholas
# 52  10035     Modjeski       Joseph     Patrick
# 53  10035     Modjeski       Joseph     Patrick
# 54  10035     Modjeski       Joseph     Patrick
# 55  10035     Modjeski       Joseph     Patrick
# 56  10035     Modjeski       Joseph     Patrick
# 57  10035     Modjeski       Joseph     Patrick
# 58  10035     Modjeski       Joseph     Patrick
# 59  10035     Modjeski       Joseph     Patrick
# 60  10035     Modjeski       Joseph     Patrick
