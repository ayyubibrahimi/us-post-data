# %%
import pandas as pd

def read_tbl():
    df = pd.read_excel("../../../../data/ND/2023-3-22/active_inactive_report_redacted-1-20231220144255.xlsx")
    return df 

df = read_tbl()

df
# Out:
#                                  Aaron, Cory B.   (6341) Unnamed: 1  \
# 0                                          Certification        NaN
# 1      Date           Status                         ...        NaN
# 2       Instructor-Police Subjects 2-03-2022      Active        NaN
# 3                General License\n11-20-2020      Active        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# 70726                                2008-08-22 00:00:00        NaN
# 70727                                2007-05-30 00:00:00        NaN
# 70728                                2005-12-21 00:00:00        NaN
# 70729                                2005-12-21 00:00:00        NaN
# 70730                                2005-08-18 00:00:00        NaN
#
#       Unnamed: 2 Unnamed: 3                   Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN                          NaN        NaN
# ...

# %%
df.head(50)
# Out:
#                               Aaron, Cory B.   (6341)  \
# 0                                       Certification
# 1   Date           Status                         ...
# 2    Instructor-Police Subjects 2-03-2022      Active
# 3             General License\n11-20-2020      Active
# 4                                                 NaN
# 5                                  Employment History
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                               Notes
# 10                                               Date
# 11                                2022-02-03 00:00:00
# 12                                2022-02-03 00:00:00
# 13                                2020-11-20 00:00:00
# 14                                2020-09-25 00:00:00
# 15                                2018-12-19 00:00:00
# ...
