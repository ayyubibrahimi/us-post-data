# %%
import re

import pandas as pd

# %%
def read_tbl():
    df = pd.read_excel(
        "../../../../data/NM/23-6-26/Copy_of_IPRA_Request_PO16267_FullData__Sheets.xlsx"
    )
    return df


df = read_tbl()

# Select the columns needed for processing
person_columns = [
    "Person Certification #",
    "Person First Name",
    "Person Middle Name",
    "Person Last Name",
    "Person Suffix",
    "Person Gender",
    "Person Date of Birth",
    "Year of Birth",
    "Person EEOC Category",
]

# Define the base names for employment columns
employment_base_columns = [
    "Employment Start Date",
    "Employment End Date",
    "Employment Appointment Type*",
    "Employment Employment Type*",
    "Employment Title/Rank (Current)",
    "Employment Status",
    "Is Primary Employment",
    "Employing Organization Name",
    "Employing Organization Agency Type",
]

# Function to get all employment-related columns


def get_employment_columns(df):
    employment_columns = []
    for col in df.columns:
        if (
            col.startswith("Employment")
            or col.startswith("Employing")
            or col == "Is Primary Employment"
        ):
            employment_columns.append(col)
    return employment_columns


# Get all employment-related columns
employment_columns = get_employment_columns(df)

# Combine person columns and employment columns
columns_to_keep = person_columns + employment_columns

# Filter the dataframe to keep only the relevant columns
filtered_df = df[columns_to_keep]

# Create an empty DataFrame to store the cleaned data
cleaned_df = pd.DataFrame()

# Function to get the base column name


def get_base_column(col):
    for base in employment_base_columns:
        if col.startswith(base):
            return base
    return col


# Function to extract number from column name


def extract_number(col):
    match = re.search(r"\d+$", col)
    return int(match.group()) if match else 0


# Group employment columns
employment_groups = {}
for col in employment_columns:
    base_col = get_base_column(col)
    if base_col not in employment_groups:
        employment_groups[base_col] = []
    employment_groups[base_col].append(col)

# Sort columns in each group
for base_col in employment_groups:
    employment_groups[base_col].sort(key=extract_number)

# Determine the maximum number of employment stints
max_stints = max(len(group) for group in employment_groups.values())

# Iterate through the rows and extract each employment stint for each person
for idx, row in filtered_df.iterrows():
    person_info = row[person_columns]

    for i in range(max_stints):
        employment_info = {}
        for base_col in employment_base_columns:
            if base_col in employment_groups and i < len(
                employment_groups[base_col]
            ):
                col = employment_groups[base_col][i]
                employment_info[base_col] = row[col]
            else:
                employment_info[base_col] = pd.NA

        # Check if at least one column in this set is not null
        if any(pd.notna(value) for value in employment_info.values()):
            # Combine person info and employment info
            combined_info = pd.concat([person_info, pd.Series(employment_info)])
            cleaned_df = pd.concat(
                [cleaned_df, combined_info.to_frame().T], ignore_index=True
            )


cleaned_df.reset_index(drop=True, inplace=True)

# %%
def rename_cols(df):
    df = df.rename(
        columns={
            "Person Certification #": "person_nbr",
            "Person First Name": "first_name",
            "Person Middle Name": "middle_name",
            "Person Last Name": "last_name",
            "Person Suffix": "suffix",
            "Person Gender": "sex",
            "Person EEOC Category": "race",
            "Year of Birth": "year_of_birth",
            "Employment Start Date": "start_date",
            "Employment End Date": "end_date",
            "Employment Employment Type*": "employment_type",
            "Employment Status": "employment_status",
            "Employing Organization Name": "agency_name",
            "Employing Organization Agency Type": "agency_type",
            "Employment Title/Rank (Current)": "rank",
        }
    )

    df = df.fillna("")

    df = df[
        [
            "person_nbr",
            "first_name",
            "middle_name",
            "last_name",
            "suffix",
            "sex",
            "year_of_birth",
            "race",
            "start_date",
            "end_date",
            "employment_type",
            "rank",
            "employment_status",
            "agency_name",
            "agency_type",
        ]
    ]
    return df


def clean_dates(df):
    df.loc[:, "start_date"] = df.start_date.astype(str).str.replace(
        r"(\w+):(\w+):(\w+)", "", regex=True
    )
    df.loc[:, "end_date"] = df.end_date.astype(str).str.replace(
        r"(\w+):(\w+):(\w+)", "", regex=True
    )
    return df


def clean_race(df):
    df.loc[:, "race"] = df.race.str.replace(r"Caucasian", "white", regex=False)
    return df


def clean_agency(df):
    df.loc[:, "agency_name"] = (
        df.agency_name.str.lower()
        .str.strip()
        .str.replace(r"dept\.", "department", regex=True)
        .str.replace(r"&", "and", regex=False)
        .str.replace(r"\bpd\b", "police department", regex=True)
        .str.replace(r"(\w+)  (\w+)", r"\1 \2", regex=True)
        .str.replace(r"mex\.", "mexico", regex=True)
    )
    df = df[~((df.agency_name.str.contains("fire")))]
    df.loc[:, "agency_name"] = df.agency_name.str.title()
    return df


def clean_special_characters(df):
    for column in df.columns:
        if df[column].dtype == "object":
            df[column] = df[column].apply(
                lambda x: "".join(
                    char for char in str(x) if ord(char) >= 32 or char == "\n"
                )
            )
    return df


def trim_whitespace(df):
    for column in df.columns:
        if df[column].dtype == "object":
            df[column] = df[column].str.strip()
    return df


def standardize_dates(df):
    date_columns = ["start_date", "end_date"]
    for col in date_columns:
        df[col] = pd.to_datetime(df[col], errors="coerce").dt.strftime(
            "%Y-%m-%d"
        )
    return df


def handle_newlines(df):
    for column in df.columns:
        if df[column].dtype == "object":
            df[column] = df[column].str.replace("\n", " ")
    return df


def ensure_utf8(df):
    for column in df.columns:
        if df[column].dtype == "object":
            df[column] = df[column].apply(
                lambda x: (
                    x.encode("utf-8", errors="ignore").decode("utf-8")
                    if isinstance(x, str)
                    else x
                )
            )
    return df

# %%
df = (
    cleaned_df.pipe(rename_cols)
    .pipe(clean_dates)
    .pipe(clean_race)
    .pipe(clean_agency)
    .pipe(clean_special_characters)
    .pipe(trim_whitespace)
    .pipe(standardize_dates)
    .pipe(handle_newlines)
    .pipe(ensure_utf8)
)

df.sort_values("person_nbr").head(40)
# Out:
# /opt/homebrew/lib/python3.12/site-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
#        person_nbr first_name middle_name  last_name suffix     sex  \
# 4560    00-0001-P     Joshua           D   Anderson           Male
# 4561    00-0001-P     Joshua           D   Anderson           Male
# 16416   00-0002-P    Phillip           B  Francisco           Male
# 16415   00-0002-P    Phillip           B  Francisco           Male
# 16414   00-0002-P    Phillip           B  Francisco           Male
# 16413   00-0002-P    Phillip           B  Francisco           Male
# 4689    00-0003-P     Angela           D    Gettler         Female
# 4688    00-0003-P     Angela           D    Gettler         Female
# 14213   00-0004-P     Robert           D      Gross           Male
# 3595    00-0005-P     Bernie           J     Guffey           Male
# 7296    00-0006-P       John           M     Kerley           Male
# 14398   00-0007-P     Carrie           E    Estrada         Female
# 14399   00-0007-P     Carrie           E    Estrada         Female
# 18379  00-00077-P    Charles           B      Yslas           Male
# 18380  00-00077-P    Charles           B      Yslas           Male
# 7365    00-0008-P      Brian           C     Murphy           Male
# 3516    00-0009-P    Darrell           Q     Savage           Male
# 14214   00-0010-P       Mike           W      Scott           Male
# 7325    00-0011-P   Bradford           A    Sousley           Male
# 7402    00-0012-P     Jerold           T      Tracy           Male
# 1855    00-0013-P   Patricia           G     Yazzie         Female
# 1854    00-0013-P   Patricia           G     Yazzie         Female
# 10653   00-0014-P       Pete               Martinez           Male
# 13996   00-0015-p    RAYMOND           D    MERRITT    Jr.    Male
# 13855   00-0016-P      Jerry           L       Hart           Male
# 13856   00-0016-P      Jerry           L       Hart           Male
# 11894   00-0017-P       Luis                Jimenez           Male
# 11895   00-0017-P       Luis                Jimenez           Male
# 14143   00-0018-P      Jerah                 Taylor           Male
# 421     00-0019-P     Milton           G       Hurd           Male
# 420     00-0019-P     Milton           G       Hurd           Male
# 419     00-0019-P     Milton           G       Hurd           Male
# 8654    00-0020-P     Joshua           R    Herrera           Male
# 8655    00-0020-P     Joshua           R    Herrera           Male
# 12903   00-0021-P     Arturo                 Orozco           Male
# 14907   00-0022-P     Marvin           L      Paulk           Male
# 14908   00-0022-P     Marvin           L      Paulk           Male
# 14909   00-0022-P     Marvin           L      Paulk           Male
# 10596   00-0023-P    William           A     Wilcox           Male
# 6558    00-0024-P      Cecil                 Melton           Male
#
#       year_of_birth              race  start_date    end_date employment_type  \
# 4560           1977             white  2000-05-22  2019-10-31       Full Time
# 4561           1977             white  1999-07-26  2000-04-17
# 16416          1976          Hispanic  2022-01-04         NaN       Full Time
# 16415          1976          Hispanic  2001-07-09  2014-08-25
# 16414          1976          Hispanic  2014-08-25  2016-08-01
# 16413          1976          Hispanic  1999-07-18  2001-06-23
# 4689           1975   Native American  1999-07-26  2000-04-29
# 4688           1975   Native American  2001-11-26  2003-05-15
# 14213          1970             white  1999-07-26  2016-08-31
# 3595           1970             white  1999-06-04  2001-10-31
# 7296           1977             white  1999-07-26  2001-12-01
# 14398          1960          Hispanic  2003-06-02  2021-04-30       Full Time
# 14399          1960          Hispanic  1996-09-03  2015-12-07
# 18379          1973          Hispanic  2008-02-25  2018-10-22       Full Time
# 18380          1973          Hispanic  1999-08-16         NaN       Full Time
# 7365           1966             white  1999-07-26  2004-02-13
# 3516           1970             white  1999-07-18  2001-03-25
# 14214          1973             white  1999-07-26  2019-07-18       Full Time
# 7325           1972             white  1999-07-26  2002-11-16
# 7402           1975             white  1999-07-26  2022-05-19       Full Time
# 1855           1975             white  1999-07-26  2008-11-06
# 1854           1975             white  2008-11-24  2010-09-12
# 10653          1959          Hispanic  1998-12-23  2006-05-22
# 13996          1968             white  1998-12-28  2018-04-06       Full Time
# 13855          1973             white  2006-07-07  2020-12-17       Full Time
# 13856          1973             white  1995-10-24  2002-05-25
# 11894          1969          Hispanic  2000-11-27  2006-07-14
# 11895          1969          Hispanic  1996-07-01  2000-11-23
# 14143          1977             white  1999-07-26  2000-11-11
# 421            1950             white  1983-01-05  1987-02-27
# 420            1950             white  1988-02-08  1991-08-06
# 419            1950             white  1999-06-07  2017-01-01
# 8654           1977          Hispanic  2009-02-02         NaN       Full Time
# 8655           1977          Hispanic  1977-05-12  2008-01-16
# 12903          1949          Hispanic  1999-07-06  2000-06-20
# 14907          1967  African American  2000-06-24  2019-01-31
# 14908          1967  African American  1999-10-04  2000-06-23
# 14909          1967  African American  1998-08-03  1998-08-14
# 10596          1949             white  1999-08-21  2001-04-27
# 6558           1968             white  1999-06-01  2000-09-07
#
#                        rank employment_status  \
# 4560               Sergeant           Retired
# 4561         Patrol Officer          Resigned
# 16416                 Chief            Active
# 16415        Deputy Sheriff          Resigned
# 16414  [Missing Title/Rank]          Resigned
# 16413        Patrol Officer          Resigned
# 4689         Deputy Sheriff       Termination
# 4688         Patrol Officer       Termination
# 14213        Deputy Sheriff           Retired
# 3595         Patrol Officer       Termination
# 7296         Patrol Officer          Resigned
# 14398        Deputy Sheriff           Retired
# 14399        Deputy Sheriff          Resigned
# 18379          Deputy Chief          Resigned
# 18380          Undersheriff            Active
# 7365         Patrol Officer          Resigned
# 3516         Patrol Officer          Resigned
# 14214                Deputy           Retired
# 7325         Patrol Officer          Resigned
# 7402           Deputy Chief           Retired
# 1855              Detective          Resigned
# 1854         Patrol Officer          Resigned
# 10653        Patrol Officer          Resigned
# 13996              Sergeant           Retired
# 13855              Sergeant           Retired
# 13856        Deputy Sheriff          Resigned
# 11894        Patrol Officer          Resigned
# 11895        Deputy Sheriff          Resigned
# 14143        Deputy Sheriff          Resigned
# 421          Deputy Sheriff          Resigned
# 420               Detective          Resigned
# 419          Patrol Officer          Resigned
# 8654         Patrol Officer            Active
# 8655            K-9 Officer          Resigned
# 12903        Patrol Officer          Resigned
# 14907               Captain           Retired
# 14908        Patrol Officer          Resigned
# 14909        Deputy Sheriff       Termination
# 10596                Ranger          Resigned
# 6558         Deputy Sheriff          Resigned
#
#                                          agency_name             agency_type
# 4560                    Bernalillo Police Department  Law Enforcement Agency
# 4561                    Farmington Police Department  Law Enforcement Agency
# 16416                   Bloomfield Police Department  Law Enforcement Agency
# 16415               San Juan County Sheriff'S Office  Law Enforcement Agency
# 16414                   Farmington Police Department  Law Enforcement Agency
# 16413                        Aztec Police Department  Law Enforcement Agency
# 4689                San Juan County Sheriff'S Office  Law Enforcement Agency
# 4688                    Bloomfield Police Department  Law Enforcement Agency
# 14213               San Juan County Sheriff'S Office  Law Enforcement Agency
# 3595                         Aztec Police Department  Law Enforcement Agency
# 7296                    Farmington Police Department  Law Enforcement Agency
# 14398               Sandoval County Sheriff'S Office  Law Enforcement Agency
# 14399               San Juan County Sheriff'S Office  Law Enforcement Agency
# 18379       New Mexico Military Institute Police Dep  Law Enforcement Agency
# 18380                 Chaves County Sheriff'S Office  Law Enforcement Agency
# 7365                    Farmington Police Department  Law Enforcement Agency
# 3516                         Aztec Police Department  Law Enforcement Agency
# 14214               San Juan County Sheriff'S Office  Law Enforcement Agency
# 7325                    Farmington Police Department  Law Enforcement Agency
# 7402                    Farmington Police Department  Law Enforcement Agency
# 1855                    Farmington Police Department  Law Enforcement Agency
# 1854                   Albuquerque Police Department  Law Enforcement Agency
# 10653                 New Mexico Emnrd - State Parks  Law Enforcement Agency
# 13996                      Ruidoso Police Department  Law Enforcement Agency
# 13855                      Roswell Police Department  Law Enforcement Agency
# 13856                De Baca County Sheriff'S Office  Law Enforcement Agency
# 11894                        New Mexico State Police  Law Enforcement Agency
# 11895                Hidalgo County Sheriff'S Office  Law Enforcement Agency
# 14143               San Juan County Sheriff'S Office  Law Enforcement Agency
# 421                 San Juan County Sheriff'S Office  Law Enforcement Agency
# 420                          Aztec Police Department  Law Enforcement Agency
# 419              Albuquerque Aviation Communications  Law Enforcement Agency
# 8654                    Las Cruces Police Department  Law Enforcement Agency
# 8655                  Sunland Park Police Department  Law Enforcement Agency
# 12903  New Mexico State University Police Department  Law Enforcement Agency
# 14907                     Santa Fe Police Department  Law Enforcement Agency
# 14908                     Espanola Police Department  Law Enforcement Agency
# 14909               Santa Fe County Sheriff'S Office  Law Enforcement Agency
# 10596                 New Mexico Emnrd - State Parks  Law Enforcement Agency
# 6558                Dona Ana County Sheriff'S Office  Law Enforcement Agency

# %%
df.sort_values("person_nbr").tail(40)
# Out:
#       person_nbr first_name middle_name     last_name suffix     sex  \
# 1037   99-0405-P       Todd           D       Cravens           Male
# 2087   99-0406-P       Mark           R         Dietz           Male
# 2549   99-0407-P      Simon           E        Drobik           Male
# 2993   99-0408-P      Dawne           B       Roberto         Female
# 2994   99-0408-P      Dawne           B       Roberto         Female
# 1181   99-0409-P       Sean           P        Higdon           Male
# 2830   99-0410-P    Heather           C        Chavez         Female
# 2168   99-0411-P      David           C        Hinson           Male
# 2136   99-0412-P      Lance           A    Hoisington           Male
# 2171   99-0413-P      Shawn           P        Lockey           Male
# 2095   99-0414-P       Mark           D        Manary           Male
# 1379   99-0415-P    Matthew           D       McElroy           Male
# 16154  99-0416-P       Eric           R          Peer           Male
# 16153  99-0416-P       Eric           R          Peer           Male
# 2147   99-0417-P     Daniel           A        Porter           Male
# 1810   99-0418-P    Anthony           S       Sedillo           Male
# 1683   99-0419-P      Carie           A      Peterson         Female
# 2616   99-0420-P      Bruce           A        Volzer           Male
# 1811   99-0421-P       Eric           J     Wasierski           Male
# 2064   99-0422-P      Scott           J  Weimerskirch           Male
# 1331   99-0423-P    Michael           A        Werner           Male
# 10639  99-0424-P     Edmund                    Schott           Male
# 7611   99-0425-P   Rachelle                     Begay         Female
# 7612   99-0425-P   Rachelle                     Begay         Female
# 13616  99-0426-P       Mark           P        Campos           Male
# 13615  99-0426-P       Mark           P        Campos           Male
# 7658   99-0427-P  Charlotte                   Platero         Female
# 9969   99-0429-P       Dean           G     Goldtooth           Male
# 10102  99-0430-P     Melvin           G          Holt           Male
# 3593   99-0431-P      Carla           M          Ondi         Female
# 3594   99-0431-P      Carla           M          Ondi         Female
# 3592   99-0431-P      Carla           M          Ondi         Female
# 9999   99-0432-P     Jarvis           F      Russette           Male
# 10047  99-0433-P  Gwendolyn           K         Smith         Female
# 9884   99-0434-P       Dale           E          West           Male
# 10046  99-0435-P     Ronald                  Williams           Male
# 9907   99-0436-P    Gilbert                    Yazzie           Male
# 10871  99-0438-P      Harry        Kyle       Bayless           Male
# 10870  99-0438-P      Harry        Kyle       Bayless           Male
# 10869  99-0438-P      Harry        Kyle       Bayless           Male
#
#       year_of_birth             race  start_date    end_date employment_type  \
# 1037           1969            white  1999-07-19         NaN       Full Time
# 2087           1972            white  1999-07-19  2014-06-13
# 2549           1972            white  1999-07-19  2020-07-10
# 2993           1972            white  1999-07-19  2015-06-20
# 2994           1972            white  2013-09-16  2015-09-02
# 1181           1972            white  1999-07-19         NaN       Full Time
# 2830           1976            white  1999-07-19  2021-05-08
# 2168           1969            white  1999-07-17  2022-08-13
# 2136           1976            white  1999-07-19  2017-06-16
# 2171           1977            white  1999-07-19  2019-09-28
# 2095           1970            white  1999-07-19  2016-01-13
# 1379           1975            white  1999-07-19         NaN       Full Time
# 16154          1977            white  2016-10-10         NaN       Full Time
# 16153          1977            white  1999-07-19  2016-10-01       Full Time
# 2147           1978            white  1999-07-19  2020-10-09       Full Time
# 1810           1972         Hispanic  1999-07-19  2018-08-08
# 1683           1974            white  1999-07-19  2007-11-10
# 2616           1973            white  1999-07-19  2018-10-01
# 1811           1974         Hispanic  1999-07-19  2003-11-07
# 2064           1972            white  1999-07-19  2015-09-18
# 1331           1968            white  1999-07-19         NaN       Full Time
# 10639          1969            white  1999-04-17  2002-08-16
# 7611           1975  Native American  1999-08-30  2002-10-10
# 7612           1975  Native American  2003-07-28  2010-10-30
# 13616          1967         Hispanic  1999-11-05  2004-12-21
# 13615          1967         Hispanic  2004-12-14  2019-09-27       Full Time
# 7658           1969  Native American  1999-06-21  2010-08-13
# 9969           1974  Native American  1998-04-01         NaN       Full Time
# 10102          1956  Native American  1999-04-12  2005-04-19
# 3593           1965            white  2009-12-08  2010-01-08
# 3594           1965            white  1999-03-15  2003-05-01
# 3592           1965            white  1997-05-27  1997-12-08
# 9999           1975  Native American  1998-05-10  2008-08-25
# 10047          1977  Native American  1999-05-03  2010-05-21
# 9884           1971            white  1999-08-08         NaN       Full Time
# 10046          1974  Native American  1999-07-19  2010-02-22
# 9907           1971  Native American  1999-08-04         NaN       Full Time
# 10871          1938            white  2000-09-27  2008-05-31
# 10870          1938            white  1999-12-03  2000-09-29
# 10869          1938            white  2009-10-03         NaN       Part Time
#
#                  rank employment_status  \
# 1037   Patrol Officer            Active
# 2087   Patrol Officer           Retired
# 2549   Patrol Officer           Retired
# 2993   Patrol Officer       Termination
# 2994          Officer          Resigned
# 1181         Sergeant            Active
# 2830   Patrol Officer           Retired
# 2168   Patrol Officer           Retired
# 2136   Patrol Officer           Retired
# 2171         Sergeant           Retired
# 2095   Patrol Officer           Retired
# 1379   Patrol Officer            Active
# 16154  Patrol Officer            Active
# 16153  Patrol Officer           Retired
# 2147         Sergeant           Retired
# 1810       Lieutenant          Resigned
# 1683   Patrol Officer          Resigned
# 2616   Patrol Officer           Retired
# 1811   Patrol Officer          Resigned
# 2064   Patrol Officer           Retired
# 1331   Patrol Officer            Active
# 10639   Park Ranger I          Resigned
# 7611   Patrol Officer          Resigned
# 7612   Patrol Officer          Resigned
# 13616  Patrol Officer          Resigned
# 13615  Patrol Officer           Retired
# 7658   Patrol Officer       Termination
# 9969   Patrol Officer            Active
# 10102  Patrol Officer       Termination
# 3593   Patrol Officer       Termination
# 3594   Patrol Officer          Resigned
# 3592   Patrol Officer       Termination
# 9999   Patrol Officer          Resigned
# 10047  Patrol Officer          Resigned
# 9884     Investigator            Active
# 10046  Patrol Officer          Resigned
# 9907   Patrol Officer            Active
# 10871  Deputy Sheriff           Retired
# 10870  Patrol Officer          Resigned
# 10869  Patrol Officer            Active
#
#                                       agency_name             agency_type
# 1037                Albuquerque Police Department  Law Enforcement Agency
# 2087                Albuquerque Police Department  Law Enforcement Agency
# 2549                Albuquerque Police Department  Law Enforcement Agency
# 2993                Albuquerque Police Department  Law Enforcement Agency
# 2994               Bosque Farms Police Department  Law Enforcement Agency
# 1181                Albuquerque Police Department  Law Enforcement Agency
# 2830                Albuquerque Police Department  Law Enforcement Agency
# 2168                Albuquerque Police Department  Law Enforcement Agency
# 2136                Albuquerque Police Department  Law Enforcement Agency
# 2171                Albuquerque Police Department  Law Enforcement Agency
# 2095                Albuquerque Police Department  Law Enforcement Agency
# 1379                Albuquerque Police Department  Law Enforcement Agency
# 16154  University Of New Mexico Police Department  Law Enforcement Agency
# 16153               Albuquerque Police Department  Law Enforcement Agency
# 2147                Albuquerque Police Department  Law Enforcement Agency
# 1810                Albuquerque Police Department  Law Enforcement Agency
# 1683                Albuquerque Police Department  Law Enforcement Agency
# 2616                Albuquerque Police Department  Law Enforcement Agency
# 1811                Albuquerque Police Department  Law Enforcement Agency
# 2064                Albuquerque Police Department  Law Enforcement Agency
# 1331                Albuquerque Police Department  Law Enforcement Agency
# 10639              New Mexico Emnrd - State Parks  Law Enforcement Agency
# 7611                     Gallup Police Department  Law Enforcement Agency
# 7612                      Hatch Police Department  Law Enforcement Agency
# 13616                     New Mexico State Police  Law Enforcement Agency
# 13615                Rio Rancho Police Department  Law Enforcement Agency
# 7658                     Gallup Police Department  Law Enforcement Agency
# 9969           Navajo Department Of Public Safety  Law Enforcement Agency
# 10102          Navajo Department Of Public Safety  Law Enforcement Agency
# 3593              Isleta Tribal Police Department  Law Enforcement Agency
# 3594           Navajo Department Of Public Safety  Law Enforcement Agency
# 3592                      Aztec Police Department  Law Enforcement Agency
# 9999           Navajo Department Of Public Safety  Law Enforcement Agency
# 10047          Navajo Department Of Public Safety  Law Enforcement Agency
# 9884           Navajo Department Of Public Safety  Law Enforcement Agency
# 10046          Navajo Department Of Public Safety  Law Enforcement Agency
# 9907           Navajo Department Of Public Safety  Law Enforcement Agency
# 10871              Chaves County Sheriff'S Office  Law Enforcement Agency
# 10870                   Capitan Police Department  Law Enforcement Agency
# 10869    New Mexico Military Institute Police Dep  Law Enforcement Agency

# %%
df.to_csv("../data/output/new-mexico-preprocessed.csv", index=False)
