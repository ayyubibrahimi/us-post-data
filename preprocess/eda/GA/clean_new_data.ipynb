# %%
import pandas as pd
from helper import clean_column_names
from uid import gen_uid

# %%
def standardize_key(df):
    df.loc[:, "OKEY"] = df.OKEY.str.lower().str.strip().str.replace(r"\s+", "", regex=True)
    return df 

def standardize_case(df):
    df.loc[:, "CASE"] = df.CASE.str.lower().str.strip().str.replace(r"\s+", "", regex=True)
    return df 


def read_sanctions():
    df = pd.read_csv("../../../data/GA/5-10-2024/officer_sanctions.csv")
    return df

def read_violations():
    df = pd.read_csv("../../../data/GA/5-10-2024/officer_violations.csv")
    return df

def read_demo():
    df = pd.read_csv("../../../data/GA/5-10-2024/officer_data.csv")
    return df


def read_history():
    df = pd.read_csv("../../../data/GA/5-10-2024/officer_employment.csv")
    return df

dfa = read_sanctions()
 
dfa = dfa.pipe(standardize_key).pipe(standardize_case)

dfb = read_violations()

dfb = dfb.pipe(standardize_key).pipe(standardize_case)

# dfb

dfc = read_demo()

dfc = dfc.pipe(standardize_key)


dfd = read_history()

dfd = dfd.pipe(standardize_key)

df1 = pd.merge(dfc, dfd, on="OKEY")
df1 = df1.pipe(clean_column_names)

df1
# Out:
#            okey last_name first_name   middle suffix   yob     sex  \
# 0       o143810    A'GIZA     DALILA      NaN    NaN  1976  Female
# 1       o255181   AAGAARD    JEFFREY     ALAN    NaN  1974    Male
# 2       o246465     AAMIR     WISHAH      NaN    NaN  1996  Female
# 3       o095227   AANERUD      DAMON        H    NaN  1972    Male
# 4       o095227   AANERUD      DAMON        H    NaN  1972    Male
# ...         ...       ...        ...      ...    ...   ...     ...
# 482658  o110791     ZYGAJ    STEPHEN        M    NaN  1962    Male
# 482659  o110791     ZYGAJ    STEPHEN        M    NaN  1962    Male
# 482660  o110791     ZYGAJ    STEPHEN        M    NaN  1962    Male
# 482661  o226212      ZYSK     JUSTIN  MICHAEL    NaN  1989    Male
# 482662  o226212      ZYSK     JUSTIN  MICHAEL    NaN  1989    Male
#
#                                                      race  \
# 0       Black or African American (Not Hispanic or Lat...
# 1                          White (Not Hispanic or Latino)
# 2                          Asian (Not Hispanic or Latino)
# 3                          White (Not Hispanic or Latino)
# 4                          White (Not Hispanic or Latino)
# ...                                                   ...
# 482658                     White (Not Hispanic or Latino)
# 482659                     White (Not Hispanic or Latino)
# 482660                     White (Not Hispanic or Latino)
# 482661                     White (Not Hispanic or Latino)
# 482662                     White (Not Hispanic or Latino)
#
#                         name                                 agency  \
# 0              A'GIZA DALILA  G1720 DEKALB COUNTY POLICE DEPARTMENT
# 1       AAGAARD JEFFREY ALAN  G1318 FRANKLIN COUNTY SHERIFFS OFFICE
# 2               AAMIR WISHAH                G1928 ELBERT COUNTY 911
# 3            AANERUD DAMON H   G1161 CHATHAM COUNTY SHERIFFS OFFICE
# 4            AANERUD DAMON H       G1244 SAVANNAH POLICE DEPARTMENT
# ...                      ...                                    ...
# 482658       ZYGAJ STEPHEN M        G1505 ATLANTA POLICE DEPARTMENT
# 482659       ZYGAJ STEPHEN M        G1505 ATLANTA POLICE DEPARTMENT
# 482660       ZYGAJ STEPHEN M        G1505 ATLANTA POLICE DEPARTMENT
# 482661   ZYSK JUSTIN MICHAEL         G1072 SMYRNA POLICE DEPARTMENT
# 482662   ZYSK JUSTIN MICHAEL         G1072 SMYRNA POLICE DEPARTMENT
#
#                  rank                                status  start_date  \
# 0       PEACE OFFICER                 Voluntary Resignation  2007-09-10
# 1              JAILOR  Actively Employed in Law Enforcement  2022-11-25
# 2       COMM. OFFICER  Actively Employed in Law Enforcement  2020-06-01
# 3              JAILOR                 Voluntary Resignation  1999-04-19
# 4       PEACE OFFICER                 Voluntary Resignation  2000-10-09
# ...               ...                                   ...         ...
# 482658  PEACE OFFICER               Rank Change - Promotion  2001-12-18
# 482659        CAPTAIN               Rank Change - Promotion  2020-01-09
# 482660          MAJOR                     Career Retirement  2022-04-14
# 482661  PEACE OFFICER                 Voluntary Resignation  2016-09-26
# 482662  COMM. OFFICER                 Voluntary Resignation  2017-02-04
#
#           end_date
# 0       2007-09-10
# 1       0000-00-00
# 2       0000-00-00
# 3       2000-10-07
# 4       2001-03-30
# ...            ...
# 482658  2020-01-08
# 482659  2022-04-13
# 482660  2023-09-20
# 482661  2017-02-03
# 482662  2018-04-28
#
# [482663 rows x 14 columns]

# %%
dfa = dfa[["SANCTION", "DATE", "CASE"]]

df2 = pd.merge(dfa, dfb, on="CASE")

df2 = df2.pipe(clean_column_names)

df2 = df2.rename(columns={"date": "action_date", "sanction": "action", "violation": "allegation", "violation_date": "allegation_date"})

def clean_action(df):
    df.loc[:, "action"] = df.action.str.lower().str.strip().str.title()
    return df

def clean_allegation(df):
    df.loc[:, "allegation"] = df.allegation.str.lower().str.strip()
    return df 

def extract_years(df):
    df.loc[:, "action_year"] = df.action_date.str.replace(r"^(\w{4})(.+)", r"\1", regex=True)
    df.loc[:, "allegation_year"] = df.allegation_date.str.replace(r"^(\w{4})(.+)", r"\1", regex=True)
    return df 

df2 = df2.pipe(clean_action).pipe(clean_allegation).pipe(extract_years)

df2 = df2.drop(columns=["name", "action_year", "allegation_year"])

df2.okey.nunique()
# Out:
# 31924

# %%
df2.head()
# Out:
#                      action action_date        case     okey  \
# 0       Probation 24 Months  2019-01-08  0011400218  o239177
# 1  Administrative Dismissal  1996-05-09  0045701195  o061330
# 2                 No Action  2018-10-12  0042591017  o152547
# 3       Probation 24 Months  2013-08-14  0005801011  o152547
# 4       Probation 24 Months  2013-08-14  0005801011  o152547
#
#                         allegation allegation_date
# 0    conduct unbecoming an officer      0000-00-00
# 1  departmental rule(s) violations      1994-07-11
# 2                sexual harassment      0000-00-00
# 3    conduct unbecoming an officer      0000-00-00
# 4                  insubordination      0000-00-00

# %%
def custom_date_parser(date_string):
    if pd.isna(date_string) or date_string == "0000-00-00":
        return pd.NaT  
    try:
        return pd.to_datetime(date_string)
    except ValueError:
        return pd.NaT  

df1['start_date'] = df1['start_date'].apply(custom_date_parser)
df1['end_date'] = df1['end_date'].apply(custom_date_parser)
df2['action_date'] = df2['action_date'].apply(custom_date_parser)
df2['allegation_date'] = df2['allegation_date'].apply(custom_date_parser)

df_merged = pd.merge(df1, df2, on='okey', how='left')

# Create a new column to indicate if action_date or allegation_date falls within start and end date range
df_merged['within_range'] = (
    ((df_merged['action_date'] >= df_merged['start_date']) & (df_merged['action_date'] <= df_merged['end_date'])) |
    ((df_merged['allegation_date'] >= df_merged['start_date']) & (df_merged['allegation_date'] <= df_merged['end_date'])) |
    (df_merged['end_date'].isnull())
)

# Filter the merged DataFrame to keep only rows where action_date or allegation_date is within range
df_final = df_merged[df_merged['within_range']]

df_final
# Out:
#            okey last_name first_name middle suffix   yob     sex  \
# 1       o255181   AAGAARD    JEFFREY   ALAN    NaN  1974    Male
# 2       o246465     AAMIR     WISHAH    NaN    NaN  1996  Female
# 6       o095227   AANERUD      DAMON      H    NaN  1972    Male
# 9       o258654     AARON        ANN  MYREE    NaN  1997  Female
# 15      o061330     AARON     AUDREY      R    NaN  1951  Female
# ...         ...       ...        ...    ...    ...   ...     ...
# 620771  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
# 620772  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
# 620773  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
# 620774  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
# 620784  o136250   ZYDONYK      ASHBY      L    NaN  1985    Male
#
#                                                      race  \
# 1                          White (Not Hispanic or Latino)
# 2                          Asian (Not Hispanic or Latino)
# 6                          White (Not Hispanic or Latino)
# 9                          White (Not Hispanic or Latino)
# 15      Black or African American (Not Hispanic or Lat...
# ...                                                   ...
# 620771                     White (Not Hispanic or Latino)
# 620772                     White (Not Hispanic or Latino)
# 620773                     White (Not Hispanic or Latino)
# 620774                     White (Not Hispanic or Latino)
# 620784                     White (Not Hispanic or Latino)
#
#                         name                                   agency  \
# 1       AAGAARD JEFFREY ALAN    G1318 FRANKLIN COUNTY SHERIFFS OFFICE
# 2               AAMIR WISHAH                  G1928 ELBERT COUNTY 911
# 6            AANERUD DAMON H           G1177 POOLER POLICE DEPARTMENT
# 9            AARON ANN MYREE  G1533 OGLETHORPE COUNTY SHERIFFS OFFICE
# 15            AARON AUDREY R        G1276 METRO STATE PRISON/INACTIVE
# ...                      ...                                      ...
# 620771     ZWIERKO MICHAEL R        G1693 ELLAVILLE POLICE DEPARTMENT
# 620772     ZWIERKO MICHAEL R        G1693 ELLAVILLE POLICE DEPARTMENT
# 620773     ZWIERKO MICHAEL R        G1693 ELLAVILLE POLICE DEPARTMENT
# 620774     ZWIERKO MICHAEL R        G1693 ELLAVILLE POLICE DEPARTMENT
# 620784       ZYDONYK ASHBY L        G1587 NEWINGTON POLICE DEPARTMENT
#
#                  rank                                status start_date  \
# 1              JAILOR  Actively Employed in Law Enforcement 2022-11-25
# 2       COMM. OFFICER  Actively Employed in Law Enforcement 2020-06-01
# 6            SERGEANT  Actively Employed in Law Enforcement 2009-09-28
# 9       COMM. OFFICER  Actively Employed in Law Enforcement 2023-07-24
# 15      PEACE OFFICER                            Terminated 1994-02-01
# ...               ...                                   ...        ...
# 620771  PEACE OFFICER  Actively Employed in Law Enforcement 2020-11-06
# 620772  PEACE OFFICER  Actively Employed in Law Enforcement 2020-11-06
# 620773  PEACE OFFICER  Actively Employed in Law Enforcement 2020-11-06
# 620774  PEACE OFFICER  Actively Employed in Law Enforcement 2020-11-06
# 620784          CHIEF  Actively Employed in Law Enforcement 2021-01-01
#
#          end_date                          action action_date        case  \
# 1             NaT                             NaN         NaT         NaN
# 2             NaT                             NaN         NaT         NaN
# 6             NaT                             NaN         NaT         NaN
# 9             NaT                             NaN         NaT         NaN
# 15     1994-07-11        Administrative Dismissal  1996-05-09  0045701195
# ...           ...                             ...         ...         ...
# 620771        NaT             Probation 36 Months  2011-06-08  0054361007
# 620772        NaT  Reinstatement Of Certification  2011-06-08  0054361007
# 620773        NaT  Reinstatement Of Certification  2011-06-08  0054361007
# 620774        NaT  Reinstatement Of Certification  2011-06-08  0054361007
# 620784        NaT                             NaN         NaT         NaN
#
#                                       allegation allegation_date  within_range
# 1                                            NaN             NaT          True
# 2                                            NaN             NaT          True
# 6                                            NaN             NaT          True
# 9                                            NaN             NaT          True
# 15               departmental rule(s) violations      1994-07-11          True
# ...                                          ...             ...           ...
# 620771  possession of controlled drugs - cocaine      2007-09-05          True
# 620772           departmental rule(s) violations      2007-09-05          True
# 620773       tested positive for drugs in system      2007-09-05          True
# 620774  possession of controlled drugs - cocaine      2007-09-05          True
# 620784                                       NaN             NaT          True
#
# [117036 rows x 20 columns]

# %%
# Filter out rows where the 'allegation' column is missing (NaN)
df_final_allegation = df_final[df_final['allegation'].notna()]

df_final_allegation
# Out:
#            okey last_name first_name middle suffix   yob     sex  \
# 15      o061330     AARON     AUDREY      R    NaN  1951  Female
# 121     o097012      ABAD   GILBERTO    NaN    NaN  1972    Male
# 122     o097012      ABAD   GILBERTO    NaN    NaN  1972    Male
# 127     o080105      ABAD     JOSEPH      A    NaN  1972    Male
# 128     o080105      ABAD     JOSEPH      A    NaN  1972    Male
# ...         ...       ...        ...    ...    ...   ...     ...
# 620770  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
# 620771  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
# 620772  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
# 620773  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
# 620774  o133176   ZWIERKO    MICHAEL      R    NaN  1981    Male
#
#                                                      race               name  \
# 15      Black or African American (Not Hispanic or Lat...     AARON AUDREY R
# 121                                    Hispanic or Latino      ABAD GILBERTO
# 122                                    Hispanic or Latino      ABAD GILBERTO
# 127                        White (Not Hispanic or Latino)      ABAD JOSEPH A
# 128                        White (Not Hispanic or Latino)      ABAD JOSEPH A
# ...                                                   ...                ...
# 620770                     White (Not Hispanic or Latino)  ZWIERKO MICHAEL R
# 620771                     White (Not Hispanic or Latino)  ZWIERKO MICHAEL R
# 620772                     White (Not Hispanic or Latino)  ZWIERKO MICHAEL R
# 620773                     White (Not Hispanic or Latino)  ZWIERKO MICHAEL R
# 620774                     White (Not Hispanic or Latino)  ZWIERKO MICHAEL R
#
#                                    agency            rank  \
# 15      G1276 METRO STATE PRISON/INACTIVE   PEACE OFFICER
# 121       G1505 ATLANTA POLICE DEPARTMENT   PEACE OFFICER
# 122       G1505 ATLANTA POLICE DEPARTMENT   PEACE OFFICER
# 127        G1065 TIFTON POLICE DEPARTMENT  POLICE OFFICER
# 128        G1065 TIFTON POLICE DEPARTMENT  POLICE OFFICER
# ...                                   ...             ...
# 620770  G1693 ELLAVILLE POLICE DEPARTMENT   PEACE OFFICER
# 620771  G1693 ELLAVILLE POLICE DEPARTMENT   PEACE OFFICER
# 620772  G1693 ELLAVILLE POLICE DEPARTMENT   PEACE OFFICER
# 620773  G1693 ELLAVILLE POLICE DEPARTMENT   PEACE OFFICER
# 620774  G1693 ELLAVILLE POLICE DEPARTMENT   PEACE OFFICER
#
#                                       status start_date   end_date  \
# 15                                Terminated 1994-02-01 1994-07-11
# 121          Resigned in Lieu of Termination 1999-12-21 2003-07-03
# 122          Resigned in Lieu of Termination 1999-12-21 2003-07-03
# 127                        Career Retirement 2014-11-30 2023-02-28
# 128                        Career Retirement 2014-11-30 2023-02-28
# ...                                      ...        ...        ...
# 620770  Actively Employed in Law Enforcement 2020-11-06        NaT
# 620771  Actively Employed in Law Enforcement 2020-11-06        NaT
# 620772  Actively Employed in Law Enforcement 2020-11-06        NaT
# 620773  Actively Employed in Law Enforcement 2020-11-06        NaT
# 620774  Actively Employed in Law Enforcement 2020-11-06        NaT
#
#                                 action action_date        case  \
# 15            Administrative Dismissal  1996-05-09  0045701195
# 121               Revoke Certification  2004-04-08  0024490603
# 122               Revoke Certification  2004-04-08  0024490603
# 127                          No Action  2016-04-08  0057951114
# 128                          No Action  2016-04-08  0057951114
# ...                                ...         ...         ...
# 620770             Probation 36 Months  2011-06-08  0054361007
# 620771             Probation 36 Months  2011-06-08  0054361007
# 620772  Reinstatement Of Certification  2011-06-08  0054361007
# 620773  Reinstatement Of Certification  2011-06-08  0054361007
# 620774  Reinstatement Of Certification  2011-06-08  0054361007
#
#                                         allegation allegation_date  \
# 15                 departmental rule(s) violations      1994-07-11
# 121                              violation of oath      2003-04-29
# 122      sexual assault against persons in custody      2003-04-29
# 127     false accusations against fellow employees             NaT
# 128                                neglect of duty             NaT
# ...                                            ...             ...
# 620770         tested positive for drugs in system      2007-09-05
# 620771    possession of controlled drugs - cocaine      2007-09-05
# 620772             departmental rule(s) violations      2007-09-05
# 620773         tested positive for drugs in system      2007-09-05
# 620774    possession of controlled drugs - cocaine      2007-09-05
#
#         within_range
# 15              True
# 121             True
# 122             True
# 127             True
# 128             True
# ...              ...
# 620770          True
# 620771          True
# 620772          True
# 620773          True
# 620774          True
#
# [60571 rows x 20 columns]

# %%
df_final_allegation.okey.nunique()
# Out:
# 20195
