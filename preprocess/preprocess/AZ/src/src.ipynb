# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../../../download/data/Arizona/Arizona_index.csv")

    df = df.drop(columns=["suffix", "year_of_birth", "age", "type"])

    df = df.rename(columns={"agency": "agency_name"})
    return df

df = read_tbl()

df
# Out:
#        person_nbr               full_name first_name middle_name  \
# 0           16814           GAIL L AAMODT       GAIL           L
# 1            8754        JEFFREY L AAMOLD    JEFFREY           L
# 2           36983            TODD W AARON       TODD           W
# 3           20341  DEBORAH K AARON-GREENE    DEBORAH           K
# 4           21171        ANTHONY J ABALOS    ANTHONY           J
# ...           ...                     ...        ...         ...
# 63750       66336    NICHOLAS JOHN ZWEMKE   NICHOLAS        JOHN
# 63751       30483        WESLEY P ZYGMONT     WESLEY           P
# 63752       30627        JARED J ZYGOWICZ      JARED           J
# 63753       39007            WAYNE A ZYSK      WAYNE           A
# 63754       66194   JERRY MATTHEW ZYWCZYK      JERRY     MATTHEW
#
#           last_name                   agency_name               rank  \
# 0            AAMODT     Phoenix Police Department  LEVEL 1 (Officer)
# 1            AAMOLD     Phoenix Police Department  LEVEL 1 (Officer)
# 2             AARON    Mohave Cty Sheriffs Office  LEVEL 1 (Officer)
# 3      AARON-GREENE     Phoenix Police Department  LEVEL 1 (Officer)
# 4            ABALOS        Mesa Police Department  LEVEL 4 (Command)
# ...             ...                           ...                ...
# 63750        ZWEMKE     Phoenix Police Department  LEVEL 1 (Officer)
# 63751       ZYGMONT    Glendale Police Department  LEVEL 1 (Officer)
# 63752      ZYGOWICZ    Chandler Police Department  LEVEL 1 (Officer)
# 63753          ZYSK  Maricopa Cty Sheriffs Office  LEVEL 1 (Officer)
# 63754       ZYWCZYK    Chandler Police Department  LEVEL 1 (Officer)
#
#        start_date    end_date current_certificate_status
# 0      1991-07-15  2021-11-30                   Inactive
# 1      1986-10-06  1987-06-18                     Lapsed
# 2      2006-08-13         NaN                     Active
# 3      1977-06-27  1981-07-22                     Lapsed
# 4      1991-01-07         NaN                     Active
# ...           ...         ...                        ...
# 63750  2019-08-12         NaN                     Active
# 63751  2000-11-27  2019-01-24                     Lapsed
# 63752  2001-01-02  2011-02-15     Relinquished Voluntary
# 63753  2007-11-26  2008-09-10                     Lapsed
# 63754  2019-07-08         NaN                     Active
#
# [63755 rows x 10 columns]

# %%
df.to_csv("../data/output/arizona_index.csv", index=False)
