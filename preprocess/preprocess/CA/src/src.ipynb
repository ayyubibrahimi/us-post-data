# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../../../download/data/California/California_index.csv")

    df = df.rename(columns={"agcy_name": "agency_name"})

    return df 

df = read_tbl()

df
# Out:
# /var/folders/4r/jhc99db14v58mjmncgtry0kc0000gn/T/ipykernel_9527/870184166.py:2: DtypeWarning: Columns (0,4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../../download/data/California/California_index.csv")
#        person_nbr               full_name       last_name first_name  \
# 0         B00-P18    PATRICK E RICHARDSON      RICHARDSON    PATRICK
# 1         B00-P18    PATRICK E RICHARDSON      RICHARDSON    PATRICK
# 2         B00-P18    PATRICK E RICHARDSON      RICHARDSON    PATRICK
# 3         B22-C55  DANIEL WILLIARD HARVEY          HARVEY     DANIEL
# 4         A68-P63        ROBERT DON PRICE           PRICE     ROBERT
# ...           ...                     ...             ...        ...
# 584873     293927    LUCIO HERRERA ORTEGA  HERRERA ORTEGA      LUCIO
# 584874     293928    JOSE F DIAZ PENALOZA   DIAZ PENALOZA       JOSE
# 584875     293928    JOSE F DIAZ PENALOZA   DIAZ PENALOZA       JOSE
# 584876     293929       CRISTIAN G GAMBOA          GAMBOA   CRISTIAN
# 584877     293929       CRISTIAN G GAMBOA          GAMBOA   CRISTIAN
#
#        middle_name middle_initial suffix  \
# 0                E              E    NaN
# 1                E              E    NaN
# 2                E              E    NaN
# 3         WILLIARD              W    NaN
# 4              DON              D    NaN
# ...            ...            ...    ...
# 584873         NaN            NaN    NaN
# 584874         NaN              F    NaN
# 584875         NaN              F    NaN
# 584876         NaN              G    NaN
# 584877         NaN              G    NaN
#
#                                               agency_name         type  \
# 0                                             GLENDALE PD       POLICE
# 1                                        BEVERLY HILLS PD       POLICE
# 2                                             GLENDALE PD       POLICE
# 3                                              SEASIDE PD       POLICE
# 4                                          LOS ANGELES PD       POLICE
# ...                                                   ...          ...
# 584873                      934: HIGH DESERT STATE PRISON  CORRECTIONS
# 584874  048: RA MCGEE CORR TRAIN CNTR -AKA- RICHARD A ...  CORRECTIONS
# 584875                      095: SAN QUENTIN STATE PRISON  CORRECTIONS
# 584876  048: RA MCGEE CORR TRAIN CNTR -AKA- RICHARD A ...  CORRECTIONS
# 584877                     674: CA. STATE PRISON - SOLANO  CORRECTIONS
#
#                              rank  start_date    end_date
# 0                              PO  1979-07-03  1982-06-11
# 1                              PO  1982-06-14  1982-09-24
# 2                              PO  1982-09-26  2007-07-12
# 3                             SGT  1965-05-01  1991-09-30
# 4                              PO  1993-01-22  2014-08-10
# ...                           ...         ...         ...
# 584873  662: CORRECTIONAL OFFICER  2019-04-01         NaN
# 584874  662: CORRECTIONAL OFFICER  2023-03-20         NaN
# 584875  662: CORRECTIONAL OFFICER  2023-06-19         NaN
# 584876  662: CORRECTIONAL OFFICER  2019-10-15         NaN
# 584877  662: CORRECTIONAL OFFICER  2020-01-27         NaN
#
# [584878 rows x 12 columns]

# %%
df.to_csv("../data/output/california_index.csv", index=False)

# %%
df.isna().sum()
# Out:
# person_nbr             0
# full_name              0
# last_name             30
# first_name          2187
# middle_name       228625
# middle_initial    117716
# suffix            565296
# agency_name            0
# type                   0
# rank                   8
# start_date            86
# end_date          191318
# dtype: int64
