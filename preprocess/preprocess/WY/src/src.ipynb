# %%
import pandas as pd

# %%
def read_tbl():
    df = pd.read_csv("../../../download/data/Wyoming/wy-2023-index-enhanced.csv")

    df = df.drop(columns=["middle_name", "suffix", "year_of_birth", "age", "agency_city", "agency_state", "type"])

    df = df.rename(columns={"employment_status": "separation_reason", "agency_type": "type", "agency": "agency_name"})


    return df 


df = read_tbl()

df
# Out:
#       person_nbr          full_name first_name  last_name  \
# 0      0000-4417  MICHAEL SCHINDLER    MICHAEL  SCHINDLER
# 1      0004-0627          ALAN KIRK       ALAN       KIRK
# 2      0004-0627          ALAN KIRK       ALAN       KIRK
# 3      0005-3387     JOHN GUTIERREZ       JOHN  GUTIERREZ
# 4      0005-3387     JOHN GUTIERREZ       JOHN  GUTIERREZ
# ...          ...                ...        ...        ...
# 11628  9988-7500        TODD MORGAN       TODD     MORGAN
# 11629  9995-2684      SANDRA ARNOLD     SANDRA     ARNOLD
# 11630  9996-5444      DUSTIN KIRSCH     DUSTIN     KIRSCH
# 11631  9996-5444      DUSTIN KIRSCH     DUSTIN     KIRSCH
# 11632  9996-5444      DUSTIN KIRSCH     DUSTIN     KIRSCH
#
#                                          agency_name  \
# 0                       PARK COUNTY SHERIFF'S OFFICE
# 1                    NATRONA COUNTY SHERIFF'S OFFICE
# 2                    NATRONA COUNTY SHERIFF'S OFFICE
# 3      LARAMIE COUNTY COMBINED COMMUNICATIONS CENTER
# 4                     OTHER EMPLOYMENT (NON-WYOMING)
# ...                                              ...
# 11628                      JACKSON POLICE DEPARTMENT
# 11629                         WYOMING HIGHWAY PATROL
# 11630               WYOMING GAME AND FISH DEPARTMENT
# 11631               CONVERSE COUNTY SHERIFF'S OFFICE
# 11632               CONVERSE COUNTY SHERIFF'S OFFICE
#
#                             rank  start_date    end_date person_status  \
# 0              DETENTION OFFICER  2023-05-05         NaN        ACTIVE
# 1      RESERVE DETENTION OFFICER  2018-01-02         NaN        ACTIVE
# 2                  PEACE OFFICER  2012-09-06         NaN        ACTIVE
# 3                     DISPATCHER  2005-07-01         NaN        ACTIVE
# 4                     DISPATCHER  2002-03-01  2004-06-30        ACTIVE
# ...                          ...         ...         ...           ...
# 11628              PEACE OFFICER  2014-07-07         NaN        ACTIVE
# 11629              PEACE OFFICER  2010-08-16         NaN      INACTIVE
# 11630              PEACE OFFICER  2023-04-06         NaN        ACTIVE
# 11631              PEACE OFFICER  2009-07-17  2023-03-31        ACTIVE
# 11632          DETENTION OFFICER  2008-01-02  2023-03-31        ACTIVE
#
#       employment_type separation_reason primary_employment                type
# 0           FULL TIME            ACTIVE               True     SHERIFF OFFICES
# 1             RESERVE            ACTIVE              False     SHERIFF OFFICES
# 2           FULL TIME            ACTIVE               True     SHERIFF OFFICES
# 3           FULL TIME            ACTIVE               True      COMMUNICATIONS
# 4           FULL TIME         SEPARATED              False               OTHER
# ...               ...               ...                ...                 ...
# 11628       FULL TIME            ACTIVE               True  POLICE DEPARTMENTS
# 11629       FULL TIME            ACTIVE               True      STATE AGENCIES
# 11630       FULL TIME            ACTIVE               True      STATE AGENCIES
# 11631       FULL TIME         SEPARATED              False     SHERIFF OFFICES
# 11632       PART TIME         SEPARATED              False     SHERIFF OFFICES
#
# [11633 rows x 13 columns]

# %%
df.to_csv("../data/output/wyoming_index.csv", index=False)
