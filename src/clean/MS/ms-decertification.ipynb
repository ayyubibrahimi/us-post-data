# 5          North Central TF  Allowed to resign at the conclusion of an inve...
# 6            Tunica Co S.O.  Purposely and knowingly take and misappropriat...
# 7        Jefferson Co. S.O.                Manslaughter/Falsifying Application
# 8          Forrest Gen Hosp              Pre Trial Diversion for Grand Larceny
# 9          Brooksville P.D.  Pled Assault in Texas, obtained certificate by...
# 10              Tupelo P.D.  Pled guilty to obstruction of justice, and acc...
# 11           Inverness P.D.  Embezzlement of a public official (held two he...
# 12           Inverness P.D.      Pled pre trial diversion - sex with prisioner
# 13          Clarksdale P.D.                Misrepresented the facts of a death
# 14           Itta Bena P.D.                        Embezzlement plea, expunged
# 15             Natchez P.D.  Trying to pay an officer to dismiss a drug cha...
# 16            Hinds Co S.O.  While supervising convicted felon on probation...
# 17         Brooksville P.D.                Misconduct - Receiving Stolen Goods
# 18          Yazoo City P.D.  Failed mandatory drug test and admitted use of...
# 19        Olive Branch P.D.  Recovered money from bank robbery and kept for...
# 20            Hinds Co S.O.       Theft of a cell phone belonging to a suspect
# 21           Greenville P.D                    Misconduct - Misuse of Gas Card
# 22             Jackson P.D.                Misconduct - Receiving Stolen Goods
# 23             Madison P.D.      Shoplifting while working in law enforcement.
# 24  Jefferson Davis Co S.O.          Embezzlement - Post-Guilty-plea dismissal
# 25         Hattiesburg P.D.          Theft of money from Hattiesburg evidence.
# 26             Pike Co S.O.   Pled guilty to receiving Stolen Goods - expunged
# 27          West Point P.D.     Charge of bribery reduced to false information
# 28               Pearl P.D.                 Embezzlement - Pre-trial Diversion
# 29           Cleveland P.D.                                         Extortion
# 30            Meridian P.D.                    Misconduct - Misuse of Gas Card

# %%
# df = df.rename(columns={"Unnamed: 1": "first_name", "Unnamed: 2": "last_name", "Unnamed: 4": "location"})

# %%
# df.location.unique()

# %%
# df.loc[:, "location"] = df.location.str.lower()

# df = df[df.location.isin(["louisiana"])]

# def clean_names(df):
#     df.loc[:, "first_name"] = df.first_name.str.lower().str.strip()
#     df.loc[:, "last_name"] = df.last_name.str.lower().str.strip()
#     return df 

# df = df.pipe(clean_names)

# %%
# df

# %%
# df = df.rename(columns={"Branch/State": "location"})

# df.loc[:, "location"] = df.location.str.lower()

# df = df[df.location.isin(["louisiana"])]

# df = df.rename(columns={"First Name": "first_name", "Last Name": "last_name"})

# %%
# def clean_names(df):
#     df.loc[:, "first_name"] = df.first_name.str.lower().str.strip()
#     df.loc[:, "last_name"] = df.last_name.str.lower().str.strip()
#     return df 

# df = df.pipe(clean_names)
